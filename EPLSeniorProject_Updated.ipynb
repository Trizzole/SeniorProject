# %% [markdown]
# <a href="https://colab.research.google.com/github/Trizzole/SeniorProject/blob/main/EPLSeniorProject_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We start out by importing all of the libraries that we will need for the project and mount the drive

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Normal config stuff and data prep

# %%
# Change disply options to be able to view more rows and columns

pd.set_option("display.max_rows", 100, "display.max_columns", None)

# %%
# Import data for the English Premier League Season 2016-2017
data1617 = pd.read_csv('/content/drive/MyDrive/season-1617.csv')
# Add Gamenum column for game number of the season
data1617['Gamenum'] = range(1, len(data1617) + 1)

### Option to remove some betting columns
#for x in range(0,39):
 # data1617.drop(data1617.columns[[64-x]], axis=1, inplace = True)

#data1617

# %%
# Import data for the English Premier League Season 2017-2018
data1718 = pd.read_csv('/content/drive/MyDrive/season-1718.csv')
# Add Gamenum column for game number of the season
data1718['Gamenum'] = range(1, len(data1718) + 1)

### Option to remove some betting columns
#for x in range(0,39):
 # data1718.drop(data1718.columns[[64-x]], axis=1, inplace = True)

#data1718

# %%
# Import data for the English Premier League Season 2018-2019
data1819 = pd.read_csv('/content/drive/MyDrive/season-1819.csv')
# Add Gamenum column for game number of the season
data1819['Gamenum'] = range(1, len(data1819) + 1)

### Option to remove some betting columns
#for x in range(0,36):
 # data1819.drop(data1819.columns[[61-x]], axis=1, inplace = True)

#data1819

# %%
# Creates dataframe with all 3 seaons together
# all games are in chronological order
alldata = pd.concat([data1617,data1718,data1819])
alldata
# Data integrity check
alldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1140 entries, 0 to 379
# Data columns (total 66 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       1140 non-null   object
#  1   Date      1140 non-null   object
#  2   HomeTeam  1140 non-null   object
#  3   AwayTeam  1140 non-null   object
#  4   FTHG      1140 non-null   int64
#  5   FTAG      1140 non-null   int64
#  6   FTR       1140 non-null   object
#  7   HTHG      1140 non-null   int64
#  8   HTAG      1140 non-null   int64
#  9   HTR       1140 non-null   object
#  10  Referee   1140 non-null   object
#  11  HS        1140 non-null   int64
#  12  AS        1140 non-null   int64
#  13  HST       1140 non-null   int64
#  14  AST       1140 non-null   int64
#  15  HF        1140 non-null   int64
#  16  AF        1140 non-null   int64
#  17  HC        1140 non-null   int64
#  18  AC        1140 non-null   int64
#  19  HY        1140 non-null   int64
# ...

# %%
alldata['HomeTeam'].unique()
#26 teams
# Out:
# array(['Burnley', 'Crystal Palace', 'Everton', 'Hull', 'Man City',
#        'Middlesbrough', 'Southampton', 'Arsenal', 'Bournemouth',
#        'Chelsea', 'Man United', 'Leicester', 'Stoke', 'Swansea',
#        'Tottenham', 'Watford', 'West Brom', 'Sunderland', 'West Ham',
#        'Liverpool', 'Brighton', 'Newcastle', 'Huddersfield', 'Fulham',
#        'Wolves', 'Cardiff'], dtype=object)

# %%
alldata
for index, row in alldata.iterrows():
  print(row['HomeTeam'],row['AwayTeam'])
# Out:
# Burnley Swansea
# Crystal Palace West Brom
# Everton Tottenham
# Hull Leicester
# Man City Sunderland
# Middlesbrough Stoke
# Southampton Watford
# Arsenal Liverpool
# Bournemouth Man United
# Chelsea West Ham
# Man United Southampton
# Burnley Liverpool
# Leicester Arsenal
# Stoke Man City
# Swansea Hull
# Tottenham Crystal Palace
# Watford Chelsea
# West Brom Everton
# Sunderland Middlesbrough
# West Ham Bournemouth
# Chelsea Burnley
# Crystal Palace Bournemouth
# Everton Stoke
# Hull Man United
# Leicester Swansea
# Southampton Sunderland
# Tottenham Liverpool
# Watford Arsenal
# Man City West Ham
# West Brom Middlesbrough
# Arsenal Southampton
# Bournemouth West Brom
# Burnley Hull
# Liverpool Leicester
# Man United Man City
# Middlesbrough Crystal Palace
# Stoke Tottenham
# West Ham Watford
# Swansea Chelsea
# Sunderland Everton
# Chelsea Liverpool
# Everton Middlesbrough
# Hull Arsenal
# Leicester Burnley
# Man City Bournemouth
# West Brom West Ham
# Crystal Palace Stoke
# ...

# %%
#Creates 2 datasets that give counts and sums by Home Team
HomeTeamCount = alldata.groupby(['HomeTeam']).count()
HomeTeamCount['Gamenum']
HomeTeamSum = alldata.groupby(['HomeTeam']).sum()
HomeTeamSum
#Summary Statistics for teams that played in all 3 seasons
print(HomeTeamSum[HomeTeamCount['Div'] == 57])
#Summary Statistics for teams that played in exactly 2 seasons
print(HomeTeamSum[HomeTeamCount['Div'] == 38])
#Summary Statstics for teams that played in only 1 season
print(HomeTeamSum[HomeTeamCount['Div'] == 19])
# Out:
#                 FTHG  FTAG  HTHG  HTAG    HS   AS  HST  AST   HF   AF   HC  \
# HomeTeam
# Arsenal          135    52    52    27   926  600  356  224  604  663  390
# Bournemouth       91    84    38    33   749  738  255  242  525  701  309
# Burnley           66    69    33    23   627  844  196  258  559  645  253
# Chelsea          124    45    56    22   997  479  371  157  522  674  397
# Crystal Palace    72    75    32    37   785  655  241  227  625  665  336
# Everton          100    59    38    26   745  625  257  207  667  638  320
# Leicester         80    67    34    31   765  660  257  222  565  563  330
# Liverpool        145    38    66    17  1025  385  388  122  509  530  383
# Man City         155    43    64    15  1069  343  414  124  519  546  432
# Man United        97    46    48    18   896  548  337  196  666  669  372
# Southampton       64    77    30    33   809  668  258  206  615  604  334
# ...

# %% [markdown]
# # Separating data into their own tables, one for each team

# %%
BurnleyData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Burnley' or row['AwayTeam'] == 'Burnley'):
    BurnleyData = BurnleyData.append(row, ignore_index = True)
BurnleyData
# Out:
#     Div        Date   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    13/08/16    Burnley    Swansea   0.0   1.0   A   0.0   0.0   D
# 1    E0    20/08/16    Burnley  Liverpool   2.0   0.0   H   2.0   0.0   H
# 2    E0    27/08/16    Chelsea    Burnley   3.0   0.0   H   2.0   0.0   H
# 3    E0    10/09/16    Burnley       Hull   1.0   1.0   D   0.0   0.0   D
# 4    E0    17/09/16  Leicester    Burnley   3.0   0.0   H   1.0   0.0   H
# ..   ..         ...        ...        ...   ...   ...  ..   ...   ...  ..
# 109  E0  13/04/2019    Burnley    Cardiff   2.0   0.0   H   1.0   0.0   H
# 110  E0  22/04/2019    Chelsea    Burnley   2.0   2.0   D   2.0   2.0   D
# 111  E0  28/04/2019    Burnley   Man City   0.0   1.0   A   0.0   0.0   D
# 112  E0  03/05/2019    Everton    Burnley   2.0   0.0   H   2.0   0.0   H
# 113  E0  12/05/2019    Burnley    Arsenal   1.0   3.0   A   0.0   0.0   D
#
#            Referee    HS    AS   HST  AST    HF    AF    HC    AC   HY   AY  \
# ...

# %%
CrystalPalaceData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Crystal Palace' or row['AwayTeam'] == 'Crystal Palace'):
    CrystalPalaceData = CrystalPalaceData.append(row, ignore_index = True)
CrystalPalaceData
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0    13/08/16  Crystal Palace       West Brom   0.0   1.0   A   0.0
# 1    E0    20/08/16       Tottenham  Crystal Palace   1.0   0.0   H   0.0
# 2    E0    27/08/16  Crystal Palace     Bournemouth   1.0   1.0   D   0.0
# 3    E0    10/09/16   Middlesbrough  Crystal Palace   1.0   2.0   A   1.0
# 4    E0    18/09/16  Crystal Palace           Stoke   4.0   1.0   H   2.0
# ..   ..         ...             ...             ...   ...   ...  ..   ...
# 109  E0  14/04/2019  Crystal Palace        Man City   1.0   3.0   A   0.0
# 110  E0  21/04/2019         Arsenal  Crystal Palace   2.0   3.0   A   0.0
# 111  E0  27/04/2019  Crystal Palace         Everton   0.0   0.0   D   0.0
# 112  E0  04/05/2019         Cardiff  Crystal Palace   2.0   3.0   A   1.0
# 113  E0  12/05/2019  Crystal Palace     Bournemouth   5.0   3.0   H   3.0
#
#      HTAG HTR      Referee    HS    AS  HST  AST    HF    AF    HC    AC   HY  \
# ...

# %%
EvertonData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Everton' or row['AwayTeam'] == 'Everton'):
    EvertonData = EvertonData.append(row, ignore_index = True)
EvertonData
# Out:
#     Div        Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0    13/08/16         Everton      Tottenham   1.0   1.0   D   1.0
# 1    E0    20/08/16       West Brom        Everton   1.0   2.0   A   1.0
# 2    E0    27/08/16         Everton          Stoke   1.0   0.0   H   0.0
# 3    E0    12/09/16      Sunderland        Everton   0.0   3.0   A   0.0
# 4    E0    17/09/16         Everton  Middlesbrough   3.0   1.0   H   3.0
# ..   ..         ...             ...            ...   ...   ...  ..   ...
# 109  E0  13/04/2019          Fulham        Everton   2.0   0.0   H   0.0
# 110  E0  21/04/2019         Everton     Man United   4.0   0.0   H   2.0
# 111  E0  27/04/2019  Crystal Palace        Everton   0.0   0.0   D   0.0
# 112  E0  03/05/2019         Everton        Burnley   2.0   0.0   H   2.0
# 113  E0  12/05/2019       Tottenham        Everton   2.0   2.0   D   1.0
#
#      HTAG HTR      Referee    HS    AS  HST  AST    HF    AF    HC    AC   HY  \
# ...

# %%
HullData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Hull' or row['AwayTeam'] == 'Hull'):
    HullData = HullData.append(row, ignore_index = True)
HullData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16            Hull       Leicester   2.0   1.0   H   1.0   0.0
# 1   E0  20/08/16         Swansea            Hull   0.0   2.0   A   0.0   0.0
# 2   E0  27/08/16            Hull      Man United   0.0   1.0   A   0.0   0.0
# 3   E0  10/09/16         Burnley            Hull   1.0   1.0   D   0.0   0.0
# 4   E0  17/09/16            Hull         Arsenal   1.0   4.0   A   0.0   1.0
# 5   E0  24/09/16       Liverpool            Hull   5.0   1.0   H   3.0   0.0
# 6   E0  01/10/16            Hull         Chelsea   0.0   2.0   A   0.0   0.0
# 7   E0  15/10/16     Bournemouth            Hull   6.0   1.0   H   3.0   1.0
# 8   E0  22/10/16            Hull           Stoke   0.0   2.0   A   0.0   1.0
# 9   E0  29/10/16         Watford            Hull   1.0   0.0   H   0.0   0.0
# 10  E0  06/11/16            Hull     Southampton   2.0   1.0   H   0.0   1.0
# ...

# %%
ManCityData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Man City' or row['AwayTeam'] == 'Man City'):
    ManCityData = ManCityData.append(row, ignore_index = True)
ManCityData
# Out:
#     Div        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    13/08/16    Man City   Sunderland   2.0   1.0   H   1.0   0.0   H
# 1    E0    20/08/16       Stoke     Man City   1.0   4.0   A   0.0   2.0   A
# 2    E0    28/08/16    Man City     West Ham   3.0   1.0   H   2.0   0.0   H
# 3    E0    10/09/16  Man United     Man City   1.0   2.0   A   1.0   2.0   A
# 4    E0    17/09/16    Man City  Bournemouth   4.0   0.0   H   2.0   0.0   H
# ..   ..         ...         ...          ...   ...   ...  ..   ...   ...  ..
# 109  E0  20/04/2019    Man City    Tottenham   1.0   0.0   H   1.0   0.0   H
# 110  E0  24/04/2019  Man United     Man City   0.0   2.0   A   0.0   0.0   D
# 111  E0  28/04/2019     Burnley     Man City   0.0   1.0   A   0.0   0.0   D
# 112  E0  06/05/2019    Man City    Leicester   1.0   0.0   H   0.0   0.0   D
# 113  E0  12/05/2019    Brighton     Man City   1.0   4.0   A   1.0   2.0   A
#
# ...

# %%
MiddlesbroughData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Middlesbrough' or row['AwayTeam'] == 'Middlesbrough'):
    MiddlesbroughData = MiddlesbroughData.append(row, ignore_index = True)
MiddlesbroughData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16   Middlesbrough           Stoke   1.0   1.0   D   1.0   0.0
# 1   E0  21/08/16      Sunderland   Middlesbrough   1.0   2.0   A   0.0   2.0
# 2   E0  28/08/16       West Brom   Middlesbrough   0.0   0.0   D   0.0   0.0
# 3   E0  10/09/16   Middlesbrough  Crystal Palace   1.0   2.0   A   1.0   1.0
# 4   E0  17/09/16         Everton   Middlesbrough   3.0   1.0   H   3.0   1.0
# 5   E0  24/09/16   Middlesbrough       Tottenham   1.0   2.0   A   0.0   2.0
# 6   E0  01/10/16        West Ham   Middlesbrough   1.0   1.0   D   0.0   0.0
# 7   E0  16/10/16   Middlesbrough         Watford   0.0   1.0   A   0.0   0.0
# 8   E0  22/10/16         Arsenal   Middlesbrough   0.0   0.0   D   0.0   0.0
# 9   E0  29/10/16   Middlesbrough     Bournemouth   2.0   0.0   H   1.0   0.0
# 10  E0  05/11/16        Man City   Middlesbrough   1.0   1.0   D   1.0   0.0
# ...

# %%
SouthamptonData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Southampton' or row['AwayTeam'] == 'Southampton'):
    SouthamptonData = SouthamptonData.append(row, ignore_index = True)
SouthamptonData
# Out:
#     Div        Date     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    13/08/16  Southampton       Watford   1.0   1.0   D   0.0   1.0
# 1    E0    19/08/16   Man United   Southampton   2.0   0.0   H   1.0   0.0
# 2    E0    27/08/16  Southampton    Sunderland   1.0   1.0   D   0.0   0.0
# 3    E0    10/09/16      Arsenal   Southampton   2.0   1.0   H   1.0   1.0
# 4    E0    18/09/16  Southampton       Swansea   1.0   0.0   H   0.0   0.0
# ..   ..         ...          ...           ...   ...   ...  ..   ...   ...
# 109  E0  20/04/2019    Newcastle   Southampton   3.0   1.0   H   2.0   0.0
# 110  E0  23/04/2019      Watford   Southampton   1.0   1.0   D   0.0   1.0
# 111  E0  27/04/2019  Southampton   Bournemouth   3.0   3.0   D   1.0   2.0
# 112  E0  04/05/2019     West Ham   Southampton   3.0   0.0   H   1.0   0.0
# 113  E0  12/05/2019  Southampton  Huddersfield   1.0   1.0   D   1.0   0.0
#
# ...

# %%
ArsenalData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Arsenal' or row['AwayTeam'] == 'Arsenal'):
    ArsenalData = ArsenalData.append(row, ignore_index = True)
ArsenalData
# Out:
#     Div        Date   HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    14/08/16    Arsenal       Liverpool   3.0   4.0   A   1.0   1.0
# 1    E0    20/08/16  Leicester         Arsenal   0.0   0.0   D   0.0   0.0
# 2    E0    27/08/16    Watford         Arsenal   1.0   3.0   A   0.0   3.0
# 3    E0    10/09/16    Arsenal     Southampton   2.0   1.0   H   1.0   1.0
# 4    E0    17/09/16       Hull         Arsenal   1.0   4.0   A   0.0   1.0
# ..   ..         ...        ...             ...   ...   ...  ..   ...   ...
# 109  E0  21/04/2019    Arsenal  Crystal Palace   2.0   3.0   A   0.0   1.0
# 110  E0  24/04/2019     Wolves         Arsenal   3.0   1.0   H   3.0   0.0
# 111  E0  28/04/2019  Leicester         Arsenal   3.0   0.0   H   0.0   0.0
# 112  E0  05/05/2019    Arsenal        Brighton   1.0   1.0   D   1.0   0.0
# 113  E0  12/05/2019    Burnley         Arsenal   1.0   3.0   A   0.0   0.0
#
# ...

# %%
ChelseaData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Chelsea' or row['AwayTeam'] == 'Chelsea'):
    ChelseaData = ChelseaData.append(row, ignore_index = True)
ChelseaData
# Out:
#     Div        Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    15/08/16     Chelsea   West Ham   2.0   1.0   H   0.0   0.0   D
# 1    E0    20/08/16     Watford    Chelsea   1.0   2.0   A   0.0   0.0   D
# 2    E0    27/08/16     Chelsea    Burnley   3.0   0.0   H   2.0   0.0   H
# 3    E0    11/09/16     Swansea    Chelsea   2.0   2.0   D   0.0   1.0   A
# 4    E0    16/09/16     Chelsea  Liverpool   1.0   2.0   A   0.0   2.0   A
# ..   ..         ...         ...        ...   ...   ...  ..   ...   ...  ..
# 109  E0  14/04/2019   Liverpool    Chelsea   2.0   0.0   H   0.0   0.0   D
# 110  E0  22/04/2019     Chelsea    Burnley   2.0   2.0   D   2.0   2.0   D
# 111  E0  28/04/2019  Man United    Chelsea   1.0   1.0   D   1.0   1.0   D
# 112  E0  05/05/2019     Chelsea    Watford   3.0   0.0   H   0.0   0.0   D
# 113  E0  12/05/2019   Leicester    Chelsea   0.0   0.0   D   0.0   0.0   D
#
# ...

# %%
BournemouthData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Bournemouth' or row['AwayTeam'] == 'Bournemouth'):
    BournemouthData = BournemouthData.append(row, ignore_index = True)
BournemouthData
# Out:
#     Div        Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    14/08/16     Bournemouth   Man United   1.0   3.0   A   0.0   1.0
# 1    E0    21/08/16        West Ham  Bournemouth   1.0   0.0   H   0.0   0.0
# 2    E0    27/08/16  Crystal Palace  Bournemouth   1.0   1.0   D   0.0   1.0
# 3    E0    10/09/16     Bournemouth    West Brom   1.0   0.0   H   0.0   0.0
# 4    E0    17/09/16        Man City  Bournemouth   4.0   0.0   H   2.0   0.0
# ..   ..         ...             ...          ...   ...   ...  ..   ...   ...
# 109  E0  13/04/2019        Brighton  Bournemouth   0.0   5.0   A   0.0   1.0
# 110  E0  20/04/2019     Bournemouth       Fulham   0.0   1.0   A   0.0   0.0
# 111  E0  27/04/2019     Southampton  Bournemouth   3.0   3.0   D   1.0   2.0
# 112  E0  04/05/2019     Bournemouth    Tottenham   1.0   0.0   H   0.0   0.0
# 113  E0  12/05/2019  Crystal Palace  Bournemouth   5.0   3.0   H   3.0   1.0
#
# ...

# %%
ManUnitedData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Man United' or row['AwayTeam'] == 'Man United'):
    ManUnitedData = ManUnitedData.append(row, ignore_index = True)
ManUnitedData
# Out:
#     Div        Date      HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    14/08/16   Bournemouth   Man United   1.0   3.0   A   0.0   1.0
# 1    E0    19/08/16    Man United  Southampton   2.0   0.0   H   1.0   0.0
# 2    E0    27/08/16          Hull   Man United   0.0   1.0   A   0.0   0.0
# 3    E0    10/09/16    Man United     Man City   1.0   2.0   A   1.0   2.0
# 4    E0    18/09/16       Watford   Man United   3.0   1.0   H   1.0   0.0
# ..   ..         ...           ...          ...   ...   ...  ..   ...   ...
# 109  E0  21/04/2019       Everton   Man United   4.0   0.0   H   2.0   0.0
# 110  E0  24/04/2019    Man United     Man City   0.0   2.0   A   0.0   0.0
# 111  E0  28/04/2019    Man United      Chelsea   1.0   1.0   D   1.0   1.0
# 112  E0  05/05/2019  Huddersfield   Man United   1.0   1.0   D   0.0   1.0
# 113  E0  12/05/2019    Man United      Cardiff   0.0   2.0   A   0.0   1.0
#
# ...

# %%
LeicesterData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Leicester' or row['AwayTeam'] == 'Leicester'):
    LeicesterData = LeicesterData.append(row, ignore_index = True)
LeicesterData
# Out:
#     Div        Date   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    13/08/16       Hull  Leicester   2.0   1.0   H   1.0   0.0   H
# 1    E0    20/08/16  Leicester    Arsenal   0.0   0.0   D   0.0   0.0   D
# 2    E0    27/08/16  Leicester    Swansea   2.0   1.0   H   1.0   0.0   H
# 3    E0    10/09/16  Liverpool  Leicester   4.0   1.0   H   2.0   1.0   H
# 4    E0    17/09/16  Leicester    Burnley   3.0   0.0   H   1.0   0.0   H
# ..   ..         ...        ...        ...   ...   ...  ..   ...   ...  ..
# 109  E0  12/04/2019  Leicester  Newcastle   0.0   1.0   A   0.0   1.0   A
# 110  E0  20/04/2019   West Ham  Leicester   2.0   2.0   D   1.0   0.0   H
# 111  E0  28/04/2019  Leicester    Arsenal   3.0   0.0   H   0.0   0.0   D
# 112  E0  06/05/2019   Man City  Leicester   1.0   0.0   H   0.0   0.0   D
# 113  E0  12/05/2019  Leicester    Chelsea   0.0   0.0   D   0.0   0.0   D
#
#            Referee    HS    AS   HST  AST    HF    AF    HC   AC   HY   AY  \
# ...

# %%
StokeData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Stoke' or row['AwayTeam'] == 'Stoke'):
    StokeData = StokeData.append(row, ignore_index = True)
StokeData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16   Middlesbrough           Stoke   1.0   1.0   D   1.0   0.0
# 1   E0  20/08/16           Stoke        Man City   1.0   4.0   A   0.0   2.0
# 2   E0  27/08/16         Everton           Stoke   1.0   0.0   H   0.0   0.0
# 3   E0  10/09/16           Stoke       Tottenham   0.0   4.0   A   0.0   1.0
# 4   E0  18/09/16  Crystal Palace           Stoke   4.0   1.0   H   2.0   0.0
# 5   E0  24/09/16           Stoke       West Brom   1.0   1.0   D   0.0   0.0
# 6   E0  02/10/16      Man United           Stoke   1.0   1.0   D   0.0   0.0
# 7   E0  15/10/16           Stoke      Sunderland   2.0   0.0   H   2.0   0.0
# 8   E0  22/10/16            Hull           Stoke   0.0   2.0   A   0.0   1.0
# 9   E0  31/10/16           Stoke         Swansea   3.0   1.0   H   1.0   1.0
# 10  E0  05/11/16        West Ham           Stoke   1.0   1.0   D   0.0   0.0
# ...

# %%
SwanseaData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Swansea' or row['AwayTeam'] == 'Swansea'):
    SwanseaData = SwanseaData.append(row, ignore_index = True)
SwanseaData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16         Burnley         Swansea   0.0   1.0   A   0.0   0.0
# 1   E0  20/08/16         Swansea            Hull   0.0   2.0   A   0.0   0.0
# 2   E0  27/08/16       Leicester         Swansea   2.0   1.0   H   1.0   0.0
# 3   E0  11/09/16         Swansea         Chelsea   2.0   2.0   D   0.0   1.0
# 4   E0  18/09/16     Southampton         Swansea   1.0   0.0   H   0.0   0.0
# 5   E0  24/09/16         Swansea        Man City   1.0   3.0   A   1.0   1.0
# 6   E0  01/10/16         Swansea       Liverpool   1.0   2.0   A   1.0   0.0
# 7   E0  15/10/16         Arsenal         Swansea   3.0   2.0   H   2.0   1.0
# 8   E0  22/10/16         Swansea         Watford   0.0   0.0   D   0.0   0.0
# 9   E0  31/10/16           Stoke         Swansea   3.0   1.0   H   1.0   1.0
# 10  E0  06/11/16         Swansea      Man United   1.0   3.0   A   0.0   3.0
# ...

# %%
TottenhamData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Tottenham' or row['AwayTeam'] == 'Tottenham'):
    TottenhamData = TottenhamData.append(row, ignore_index = True)
TottenhamData
# Out:
#     Div        Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    13/08/16      Everton       Tottenham   1.0   1.0   D   1.0   0.0
# 1    E0    20/08/16    Tottenham  Crystal Palace   1.0   0.0   H   0.0   0.0
# 2    E0    27/08/16    Tottenham       Liverpool   1.0   1.0   D   0.0   1.0
# 3    E0    10/09/16        Stoke       Tottenham   0.0   4.0   A   0.0   1.0
# 4    E0    18/09/16    Tottenham      Sunderland   1.0   0.0   H   0.0   0.0
# ..   ..         ...          ...             ...   ...   ...  ..   ...   ...
# 109  E0  20/04/2019     Man City       Tottenham   1.0   0.0   H   1.0   0.0
# 110  E0  23/04/2019    Tottenham        Brighton   1.0   0.0   H   0.0   0.0
# 111  E0  27/04/2019    Tottenham        West Ham   0.0   1.0   A   0.0   0.0
# 112  E0  04/05/2019  Bournemouth       Tottenham   1.0   0.0   H   0.0   0.0
# 113  E0  12/05/2019    Tottenham         Everton   2.0   2.0   D   1.0   0.0
#
# ...

# %%
WatfordData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Watford' or row['AwayTeam'] == 'Watford'):
    WatfordData = WatfordData.append(row, ignore_index = True)
WatfordData
# Out:
#     Div        Date      HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    13/08/16   Southampton      Watford   1.0   1.0   D   0.0   1.0
# 1    E0    20/08/16       Watford      Chelsea   1.0   2.0   A   0.0   0.0
# 2    E0    27/08/16       Watford      Arsenal   1.0   3.0   A   0.0   3.0
# 3    E0    10/09/16      West Ham      Watford   2.0   4.0   A   2.0   2.0
# 4    E0    18/09/16       Watford   Man United   3.0   1.0   H   1.0   0.0
# ..   ..         ...           ...          ...   ...   ...  ..   ...   ...
# 109  E0  20/04/2019  Huddersfield      Watford   1.0   2.0   A   0.0   1.0
# 110  E0  23/04/2019       Watford  Southampton   1.0   1.0   D   0.0   1.0
# 111  E0  27/04/2019       Watford       Wolves   1.0   2.0   A   0.0   1.0
# 112  E0  05/05/2019       Chelsea      Watford   3.0   0.0   H   0.0   0.0
# 113  E0  12/05/2019       Watford     West Ham   1.0   4.0   A   0.0   2.0
#
# ...

# %%
WestBromData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'West Brom' or row['AwayTeam'] == 'West Brom'):
    WestBromData = WestBromData.append(row, ignore_index = True)
WestBromData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16  Crystal Palace       West Brom   0.0   1.0   A   0.0   0.0
# 1   E0  20/08/16       West Brom         Everton   1.0   2.0   A   1.0   1.0
# 2   E0  28/08/16       West Brom   Middlesbrough   0.0   0.0   D   0.0   0.0
# 3   E0  10/09/16     Bournemouth       West Brom   1.0   0.0   H   0.0   0.0
# 4   E0  17/09/16       West Brom        West Ham   4.0   2.0   H   3.0   0.0
# 5   E0  24/09/16           Stoke       West Brom   1.0   1.0   D   0.0   0.0
# 6   E0  01/10/16      Sunderland       West Brom   1.0   1.0   D   0.0   1.0
# 7   E0  15/10/16       West Brom       Tottenham   1.0   1.0   D   0.0   0.0
# 8   E0  22/10/16       Liverpool       West Brom   2.0   1.0   H   2.0   0.0
# 9   E0  29/10/16       West Brom        Man City   0.0   4.0   A   0.0   2.0
# 10  E0  06/11/16       Leicester       West Brom   1.0   2.0   A   0.0   0.0
# ...

# %%
SunderlandData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Sunderland' or row['AwayTeam'] == 'Sunderland'):
    SunderlandData = SunderlandData.append(row, ignore_index = True)
SunderlandData
# Out:
#    Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0  13/08/16        Man City      Sunderland   2.0   1.0   H   1.0   0.0
# 1   E0  21/08/16      Sunderland   Middlesbrough   1.0   2.0   A   0.0   2.0
# 2   E0  27/08/16     Southampton      Sunderland   1.0   1.0   D   0.0   0.0
# 3   E0  12/09/16      Sunderland         Everton   0.0   3.0   A   0.0   0.0
# 4   E0  18/09/16       Tottenham      Sunderland   1.0   0.0   H   0.0   0.0
# 5   E0  24/09/16      Sunderland  Crystal Palace   2.0   3.0   A   1.0   0.0
# 6   E0  01/10/16      Sunderland       West Brom   1.0   1.0   D   0.0   1.0
# 7   E0  15/10/16           Stoke      Sunderland   2.0   0.0   H   2.0   0.0
# 8   E0  22/10/16        West Ham      Sunderland   1.0   0.0   H   0.0   0.0
# 9   E0  29/10/16      Sunderland         Arsenal   1.0   4.0   A   0.0   1.0
# 10  E0  05/11/16     Bournemouth      Sunderland   1.0   2.0   A   1.0   1.0
# ...

# %%
WestHamData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'West Ham' or row['AwayTeam'] == 'West Ham'):
    WestHamData = WestHamData.append(row, ignore_index = True)
WestHamData
# Out:
#     Div        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    15/08/16     Chelsea     West Ham   2.0   1.0   H   0.0   0.0   D
# 1    E0    21/08/16    West Ham  Bournemouth   1.0   0.0   H   0.0   0.0   D
# 2    E0    28/08/16    Man City     West Ham   3.0   1.0   H   2.0   0.0   H
# 3    E0    10/09/16    West Ham      Watford   2.0   4.0   A   2.0   2.0   D
# 4    E0    17/09/16   West Brom     West Ham   4.0   2.0   H   3.0   0.0   H
# ..   ..         ...         ...          ...   ...   ...  ..   ...   ...  ..
# 109  E0  13/04/2019  Man United     West Ham   2.0   1.0   H   1.0   0.0   H
# 110  E0  20/04/2019    West Ham    Leicester   2.0   2.0   D   1.0   0.0   H
# 111  E0  27/04/2019   Tottenham     West Ham   0.0   1.0   A   0.0   0.0   D
# 112  E0  04/05/2019    West Ham  Southampton   3.0   0.0   H   1.0   0.0   H
# 113  E0  12/05/2019     Watford     West Ham   1.0   4.0   A   0.0   2.0   A
#
# ...

# %%
LiverpoolData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Liverpool' or row['AwayTeam'] == 'Liverpool'):
    LiverpoolData = LiverpoolData.append(row, ignore_index = True)
LiverpoolData
# Out:
#     Div        Date   HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0    14/08/16    Arsenal     Liverpool   3.0   4.0   A   1.0   1.0   D
# 1    E0    20/08/16    Burnley     Liverpool   2.0   0.0   H   2.0   0.0   H
# 2    E0    27/08/16  Tottenham     Liverpool   1.0   1.0   D   0.0   1.0   A
# 3    E0    10/09/16  Liverpool     Leicester   4.0   1.0   H   2.0   1.0   H
# 4    E0    16/09/16    Chelsea     Liverpool   1.0   2.0   A   0.0   2.0   A
# ..   ..         ...        ...           ...   ...   ...  ..   ...   ...  ..
# 109  E0  14/04/2019  Liverpool       Chelsea   2.0   0.0   H   0.0   0.0   D
# 110  E0  21/04/2019    Cardiff     Liverpool   0.0   2.0   A   0.0   0.0   D
# 111  E0  26/04/2019  Liverpool  Huddersfield   5.0   0.0   H   3.0   0.0   H
# 112  E0  04/05/2019  Newcastle     Liverpool   2.0   3.0   A   1.0   2.0   A
# 113  E0  12/05/2019  Liverpool        Wolves   2.0   0.0   H   1.0   0.0   H
#
# ...

# %%
BrightonData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Brighton' or row['AwayTeam'] == 'Brighton'):
    BrightonData = BrightonData.append(row, ignore_index = True)
BrightonData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0    12/08/17        Brighton        Man City   0.0   2.0   A   0.0
# 1   E0    19/08/17       Leicester        Brighton   2.0   0.0   H   1.0
# 2   E0    26/08/17         Watford        Brighton   0.0   0.0   D   0.0
# 3   E0    09/09/17        Brighton       West Brom   3.0   1.0   H   1.0
# 4   E0    15/09/17     Bournemouth        Brighton   2.0   1.0   H   0.0
# 5   E0    24/09/17        Brighton       Newcastle   1.0   0.0   H   0.0
# 6   E0    01/10/17         Arsenal        Brighton   2.0   0.0   H   1.0
# 7   E0    15/10/17        Brighton         Everton   1.0   1.0   D   0.0
# 8   E0    20/10/17        West Ham        Brighton   0.0   3.0   A   0.0
# 9   E0    29/10/17        Brighton     Southampton   1.0   1.0   D   0.0
# 10  E0    04/11/17         Swansea        Brighton   0.0   1.0   A   0.0
# 11  E0    20/11/17        Brighton           Stoke   2.0   2.0   D   1.0
# ...

# %%
NewcastleData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Newcastle' or row['AwayTeam'] == 'Newcastle'):
    NewcastleData = NewcastleData.append(row, ignore_index = True)
NewcastleData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0    13/08/17       Newcastle       Tottenham   0.0   2.0   A   0.0
# 1   E0    20/08/17    Huddersfield       Newcastle   1.0   0.0   H   0.0
# 2   E0    26/08/17       Newcastle        West Ham   3.0   0.0   H   1.0
# 3   E0    10/09/17         Swansea       Newcastle   0.0   1.0   A   0.0
# 4   E0    16/09/17       Newcastle           Stoke   2.0   1.0   H   1.0
# 5   E0    24/09/17        Brighton       Newcastle   1.0   0.0   H   0.0
# 6   E0    01/10/17       Newcastle       Liverpool   1.0   1.0   D   1.0
# 7   E0    15/10/17     Southampton       Newcastle   2.0   2.0   D   0.0
# 8   E0    21/10/17       Newcastle  Crystal Palace   1.0   0.0   H   0.0
# 9   E0    30/10/17         Burnley       Newcastle   1.0   0.0   H   0.0
# 10  E0    04/11/17       Newcastle     Bournemouth   0.0   1.0   A   0.0
# 11  E0    18/11/17      Man United       Newcastle   4.0   1.0   H   2.0
# ...

# %%
HuddersfieldData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Huddersfield' or row['AwayTeam'] == 'Huddersfield'):
    HuddersfieldData = HuddersfieldData.append(row, ignore_index = True)
HuddersfieldData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0    12/08/17  Crystal Palace    Huddersfield   0.0   3.0   A   0.0
# 1   E0    20/08/17    Huddersfield       Newcastle   1.0   0.0   H   0.0
# 2   E0    26/08/17    Huddersfield     Southampton   0.0   0.0   D   0.0
# 3   E0    11/09/17        West Ham    Huddersfield   2.0   0.0   H   0.0
# 4   E0    16/09/17    Huddersfield       Leicester   1.0   1.0   D   0.0
# 5   E0    23/09/17         Burnley    Huddersfield   0.0   0.0   D   0.0
# 6   E0    30/09/17    Huddersfield       Tottenham   0.0   4.0   A   0.0
# 7   E0    14/10/17         Swansea    Huddersfield   2.0   0.0   H   1.0
# 8   E0    21/10/17    Huddersfield      Man United   2.0   1.0   H   2.0
# 9   E0    28/10/17       Liverpool    Huddersfield   3.0   0.0   H   0.0
# 10  E0    04/11/17    Huddersfield       West Brom   1.0   0.0   H   1.0
# 11  E0    18/11/17     Bournemouth    Huddersfield   4.0   0.0   H   2.0
# ...

# %%
FulhamData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Fulham' or row['AwayTeam'] == 'Fulham'):
    FulhamData = FulhamData.append(row, ignore_index = True)
FulhamData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  11/08/2018          Fulham  Crystal Palace   0.0   2.0   A   0.0
# 1   E0  18/08/2018       Tottenham          Fulham   3.0   1.0   H   1.0
# 2   E0  26/08/2018          Fulham         Burnley   4.0   2.0   H   3.0
# 3   E0  01/09/2018        Brighton          Fulham   2.0   2.0   D   0.0
# 4   E0  15/09/2018        Man City          Fulham   3.0   0.0   H   2.0
# 5   E0  22/09/2018          Fulham         Watford   1.0   1.0   D   0.0
# 6   E0  29/09/2018         Everton          Fulham   3.0   0.0   H   0.0
# 7   E0  07/10/2018          Fulham         Arsenal   1.0   5.0   A   1.0
# 8   E0  20/10/2018         Cardiff          Fulham   4.0   2.0   H   2.0
# 9   E0  27/10/2018          Fulham     Bournemouth   0.0   3.0   A   0.0
# 10  E0  05/11/2018    Huddersfield          Fulham   1.0   0.0   H   1.0
# 11  E0  11/11/2018       Liverpool          Fulham   2.0   0.0   H   1.0
# ...

# %%
WolvesData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Wolves' or row['AwayTeam'] == 'Wolves'):
    WolvesData = WolvesData.append(row, ignore_index = True)
WolvesData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  11/08/2018          Wolves         Everton   2.0   2.0   D   1.0
# 1   E0  18/08/2018       Leicester          Wolves   2.0   0.0   H   2.0
# 2   E0  25/08/2018          Wolves        Man City   1.0   1.0   D   0.0
# 3   E0  01/09/2018        West Ham          Wolves   0.0   1.0   A   0.0
# 4   E0  16/09/2018          Wolves         Burnley   1.0   0.0   H   0.0
# 5   E0  22/09/2018      Man United          Wolves   1.0   1.0   D   1.0
# 6   E0  29/09/2018          Wolves     Southampton   2.0   0.0   H   0.0
# 7   E0  06/10/2018  Crystal Palace          Wolves   0.0   1.0   A   0.0
# 8   E0  20/10/2018          Wolves         Watford   0.0   2.0   A   0.0
# 9   E0  27/10/2018        Brighton          Wolves   1.0   0.0   H   0.0
# 10  E0  03/11/2018          Wolves       Tottenham   2.0   3.0   A   0.0
# 11  E0  11/11/2018         Arsenal          Wolves   1.0   1.0   D   0.0
# ...

# %%
CardiffData = pd.DataFrame()
for index, row in alldata.iterrows():
  if(row['HomeTeam'] == 'Cardiff' or row['AwayTeam'] == 'Cardiff'):
    CardiffData = CardiffData.append(row, ignore_index = True)
CardiffData
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  11/08/2018     Bournemouth         Cardiff   2.0   0.0   H   1.0
# 1   E0  18/08/2018         Cardiff       Newcastle   0.0   0.0   D   0.0
# 2   E0  25/08/2018    Huddersfield         Cardiff   0.0   0.0   D   0.0
# 3   E0  02/09/2018         Cardiff         Arsenal   2.0   3.0   A   1.0
# 4   E0  15/09/2018         Chelsea         Cardiff   4.0   1.0   H   2.0
# 5   E0  22/09/2018         Cardiff        Man City   0.0   5.0   A   0.0
# 6   E0  30/09/2018         Cardiff         Burnley   1.0   2.0   A   0.0
# 7   E0  06/10/2018       Tottenham         Cardiff   1.0   0.0   H   1.0
# 8   E0  20/10/2018         Cardiff          Fulham   4.0   2.0   H   2.0
# 9   E0  27/10/2018       Liverpool         Cardiff   4.0   1.0   H   1.0
# 10  E0  03/11/2018         Cardiff       Leicester   0.0   1.0   A   0.0
# 11  E0  10/11/2018         Cardiff        Brighton   2.0   1.0   H   1.0
# ...

# %% [markdown]
# # Home/Away -> team columns

# %%
BurnleyData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Burnley' or row['AwayTeam'] == 'Burnley'):
    #BurnleyData = BurnleyData.append(row, ignore_index = True)

BurnleyData['Burnley_Goals'] = BurnleyData['FTHG'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['FTAG'])
BurnleyData['Opponent_Goals'] = BurnleyData['FTHG'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['FTAG'])
BurnleyData['Burnley_Shots'] = BurnleyData['HS'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AS'])
BurnleyData['Opponent_Shots'] = BurnleyData['HS'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AS'])
BurnleyData['Burnley_SoT'] = BurnleyData['HST'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AST'])
BurnleyData['Opponent_SoT'] = BurnleyData['HST'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AST'])
BurnleyData['Burnley_Goals'] = BurnleyData['FTHG'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['FTAG'])
BurnleyData['Opponent_Goals'] = BurnleyData['FTHG'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['FTAG'])
BurnleyData['Burnley_Corners'] = BurnleyData['HC'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AC'])
BurnleyData['Opponent_Corners'] = BurnleyData['HC'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AC'])
BurnleyData['Burnley_Fouls'] = BurnleyData['HF'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AF'])
BurnleyData['Opponent_Fouls'] = BurnleyData['HF'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AF'])
BurnleyData['Burnley_Yellow'] = BurnleyData['HY'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AY'])
BurnleyData['Opponent_Yellow'] = BurnleyData['HY'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AY'])
BurnleyData['Burnley_Red'] = BurnleyData['HR'].where(BurnleyData['HomeTeam'] == 'Burnley', BurnleyData['AR'])
BurnleyData['Opponent_Red'] = BurnleyData['HR'].where(BurnleyData['AwayTeam'] == 'Burnley', BurnleyData['AR'])

conditions = [
    (BurnleyData['FTR'] == 'D'),
    (BurnleyData['FTR'] == 'H') & (BurnleyData['HomeTeam'] == 'Burnley'),
    (BurnleyData['FTR'] == 'A') & (BurnleyData['AwayTeam'] == 'Burnley'),
    (BurnleyData['FTR'] == 'H') & (BurnleyData['AwayTeam'] == 'Burnley'),
    (BurnleyData['FTR'] == 'A') & (BurnleyData['HomeTeam'] == 'Burnley')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

BurnleyData['Burnley Result'] = np.select(conditions, values)


#BurnleyData

# %%
CrystalPalaceData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'CrystalPalace' or row['AwayTeam'] == 'CrystalPalace'):
    #CrystalPalaceData = CrystalPalaceData.append(row, ignore_index = True)

CrystalPalaceData['CrystalPalace_Goals'] = CrystalPalaceData['FTHG'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['FTAG'])
CrystalPalaceData['Opponent_Goals'] = CrystalPalaceData['FTHG'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['FTAG'])
CrystalPalaceData['CrystalPalace_Shots'] = CrystalPalaceData['HS'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AS'])
CrystalPalaceData['Opponent_Shots'] = CrystalPalaceData['HS'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AS'])
CrystalPalaceData['CrystalPalace_SoT'] = CrystalPalaceData['HST'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AST'])
CrystalPalaceData['Opponent_SoT'] = CrystalPalaceData['HST'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AST'])
CrystalPalaceData['CrystalPalace_Goals'] = CrystalPalaceData['FTHG'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['FTAG'])
CrystalPalaceData['Opponent_Goals'] = CrystalPalaceData['FTHG'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['FTAG'])
CrystalPalaceData['CrystalPalace_Corners'] = CrystalPalaceData['HC'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AC'])
CrystalPalaceData['Opponent_Corners'] = CrystalPalaceData['HC'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AC'])
CrystalPalaceData['CrystalPalace_Fouls'] = CrystalPalaceData['HF'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AF'])
CrystalPalaceData['Opponent_Fouls'] = CrystalPalaceData['HF'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AF'])
CrystalPalaceData['CrystalPalace_Yellow'] = CrystalPalaceData['HY'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AY'])
CrystalPalaceData['Opponent_Yellow'] = CrystalPalaceData['HY'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AY'])
CrystalPalaceData['CrystalPalace_Red'] = CrystalPalaceData['HR'].where(CrystalPalaceData['HomeTeam'] == 'CrystalPalace', CrystalPalaceData['AR'])
CrystalPalaceData['Opponent_Red'] = CrystalPalaceData['HR'].where(CrystalPalaceData['AwayTeam'] == 'CrystalPalace', CrystalPalaceData['AR'])

conditions = [
    (CrystalPalaceData['FTR'] == 'D'),
    (CrystalPalaceData['FTR'] == 'H') & (CrystalPalaceData['HomeTeam'] == 'Crystal Palace'),
    (CrystalPalaceData['FTR'] == 'A') & (CrystalPalaceData['AwayTeam'] == 'Crystal Palace'),
    (CrystalPalaceData['FTR'] == 'H') & (CrystalPalaceData['AwayTeam'] == 'Crystal Palace'),
    (CrystalPalaceData['FTR'] == 'A') & (CrystalPalaceData['HomeTeam'] == 'Crystal Palace')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

CrystalPalaceData['CrystalPalace Result'] = np.select(conditions, values)


CrystalPalaceData
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0    13/08/16  Crystal Palace       West Brom   0.0   1.0   A   0.0
# 1    E0    20/08/16       Tottenham  Crystal Palace   1.0   0.0   H   0.0
# 2    E0    27/08/16  Crystal Palace     Bournemouth   1.0   1.0   D   0.0
# 3    E0    10/09/16   Middlesbrough  Crystal Palace   1.0   2.0   A   1.0
# 4    E0    18/09/16  Crystal Palace           Stoke   4.0   1.0   H   2.0
# ..   ..         ...             ...             ...   ...   ...  ..   ...
# 109  E0  14/04/2019  Crystal Palace        Man City   1.0   3.0   A   0.0
# 110  E0  21/04/2019         Arsenal  Crystal Palace   2.0   3.0   A   0.0
# 111  E0  27/04/2019  Crystal Palace         Everton   0.0   0.0   D   0.0
# 112  E0  04/05/2019         Cardiff  Crystal Palace   2.0   3.0   A   1.0
# 113  E0  12/05/2019  Crystal Palace     Bournemouth   5.0   3.0   H   3.0
#
#      HTAG HTR      Referee    HS    AS  HST  AST    HF    AF    HC    AC   HY  \
# ...

# %%
EvertonData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Everton' or row['AwayTeam'] == 'Everton'):
    #EvertonData = EvertonData.append(row, ignore_index = True)

EvertonData['Everton_Goals'] = EvertonData['FTHG'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['FTAG'])
EvertonData['Opponent_Goals'] = EvertonData['FTHG'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['FTAG'])
EvertonData['Everton_Shots'] = EvertonData['HS'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AS'])
EvertonData['Opponent_Shots'] = EvertonData['HS'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AS'])
EvertonData['Everton_SoT'] = EvertonData['HST'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AST'])
EvertonData['Opponent_SoT'] = EvertonData['HST'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AST'])
EvertonData['Everton_Goals'] = EvertonData['FTHG'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['FTAG'])
EvertonData['Opponent_Goals'] = EvertonData['FTHG'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['FTAG'])
EvertonData['Everton_Corners'] = EvertonData['HC'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AC'])
EvertonData['Opponent_Corners'] = EvertonData['HC'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AC'])
EvertonData['Everton_Fouls'] = EvertonData['HF'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AF'])
EvertonData['Opponent_Fouls'] = EvertonData['HF'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AF'])
EvertonData['Everton_Yellow'] = EvertonData['HY'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AY'])
EvertonData['Opponent_Yellow'] = EvertonData['HY'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AY'])
EvertonData['Everton_Red'] = EvertonData['HR'].where(EvertonData['HomeTeam'] == 'Everton', EvertonData['AR'])
EvertonData['Opponent_Red'] = EvertonData['HR'].where(EvertonData['AwayTeam'] == 'Everton', EvertonData['AR'])

conditions = [
    (EvertonData['FTR'] == 'D'),
    (EvertonData['FTR'] == 'H') & (EvertonData['HomeTeam'] == 'Everton'),
    (EvertonData['FTR'] == 'A') & (EvertonData['AwayTeam'] == 'Everton'),
    (EvertonData['FTR'] == 'H') & (EvertonData['AwayTeam'] == 'Everton'),
    (EvertonData['FTR'] == 'A') & (EvertonData['HomeTeam'] == 'Everton')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

EvertonData['Everton Result'] = np.select(conditions, values)


#EvertonData

# %%
HullData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Hull' or row['AwayTeam'] == 'Hull'):
    #HullData = HullData.append(row, ignore_index = True)

HullData['Hull_Goals'] = HullData['FTHG'].where(HullData['HomeTeam'] == 'Hull', HullData['FTAG'])
HullData['Opponent_Goals'] = HullData['FTHG'].where(HullData['AwayTeam'] == 'Hull', HullData['FTAG'])
HullData['Hull_Shots'] = HullData['HS'].where(HullData['HomeTeam'] == 'Hull', HullData['AS'])
HullData['Opponent_Shots'] = HullData['HS'].where(HullData['AwayTeam'] == 'Hull', HullData['AS'])
HullData['Hull_SoT'] = HullData['HST'].where(HullData['HomeTeam'] == 'Hull', HullData['AST'])
HullData['Opponent_SoT'] = HullData['HST'].where(HullData['AwayTeam'] == 'Hull', HullData['AST'])
HullData['Hull_Goals'] = HullData['FTHG'].where(HullData['HomeTeam'] == 'Hull', HullData['FTAG'])
HullData['Opponent_Goals'] = HullData['FTHG'].where(HullData['AwayTeam'] == 'Hull', HullData['FTAG'])
HullData['Hull_Corners'] = HullData['HC'].where(HullData['HomeTeam'] == 'Hull', HullData['AC'])
HullData['Opponent_Corners'] = HullData['HC'].where(HullData['AwayTeam'] == 'Hull', HullData['AC'])
HullData['Hull_Fouls'] = HullData['HF'].where(HullData['HomeTeam'] == 'Hull', HullData['AF'])
HullData['Opponent_Fouls'] = HullData['HF'].where(HullData['AwayTeam'] == 'Hull', HullData['AF'])
HullData['Hull_Yellow'] = HullData['HY'].where(HullData['HomeTeam'] == 'Hull', HullData['AY'])
HullData['Opponent_Yellow'] = HullData['HY'].where(HullData['AwayTeam'] == 'Hull', HullData['AY'])
HullData['Hull_Red'] = HullData['HR'].where(HullData['HomeTeam'] == 'Hull', HullData['AR'])
HullData['Opponent_Red'] = HullData['HR'].where(HullData['AwayTeam'] == 'Hull', HullData['AR'])

conditions = [
    (HullData['FTR'] == 'D'),
    (HullData['FTR'] == 'H') & (HullData['HomeTeam'] == 'Hull'),
    (HullData['FTR'] == 'A') & (HullData['AwayTeam'] == 'Hull'),
    (HullData['FTR'] == 'H') & (HullData['AwayTeam'] == 'Hull'),
    (HullData['FTR'] == 'A') & (HullData['HomeTeam'] == 'Hull')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

HullData['Hull Result'] = np.select(conditions, values)


#HullData

# %%
ManCityData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'ManCity' or row['AwayTeam'] == 'ManCity'):
    #ManCityData = ManCityData.append(row, ignore_index = True)

ManCityData['ManCity_Goals'] = ManCityData['FTHG'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['FTAG'])
ManCityData['Opponent_Goals'] = ManCityData['FTHG'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['FTAG'])
ManCityData['ManCity_Shots'] = ManCityData['HS'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AS'])
ManCityData['Opponent_Shots'] = ManCityData['HS'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AS'])
ManCityData['ManCity_SoT'] = ManCityData['HST'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AST'])
ManCityData['Opponent_SoT'] = ManCityData['HST'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AST'])
ManCityData['ManCity_Goals'] = ManCityData['FTHG'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['FTAG'])
ManCityData['Opponent_Goals'] = ManCityData['FTHG'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['FTAG'])
ManCityData['ManCity_Corners'] = ManCityData['HC'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AC'])
ManCityData['Opponent_Corners'] = ManCityData['HC'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AC'])
ManCityData['ManCity_Fouls'] = ManCityData['HF'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AF'])
ManCityData['Opponent_Fouls'] = ManCityData['HF'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AF'])
ManCityData['ManCity_Yellow'] = ManCityData['HY'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AY'])
ManCityData['Opponent_Yellow'] = ManCityData['HY'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AY'])
ManCityData['ManCity_Red'] = ManCityData['HR'].where(ManCityData['HomeTeam'] == 'ManCity', ManCityData['AR'])
ManCityData['Opponent_Red'] = ManCityData['HR'].where(ManCityData['AwayTeam'] == 'ManCity', ManCityData['AR'])

conditions = [
    (ManCityData['FTR'] == 'D'),
    (ManCityData['FTR'] == 'H') & (ManCityData['HomeTeam'] == 'Man City'),
    (ManCityData['FTR'] == 'A') & (ManCityData['AwayTeam'] == 'Man City'),
    (ManCityData['FTR'] == 'H') & (ManCityData['AwayTeam'] == 'Man City'),
    (ManCityData['FTR'] == 'A') & (ManCityData['HomeTeam'] == 'Man City')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

ManCityData['ManCity Result'] = np.select(conditions, values)


#ManCityData

# %%
MiddlesbroughData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Middlesbrough' or row['AwayTeam'] == 'Middlesbrough'):
    #MiddlesbroughData = MiddlesbroughData.append(row, ignore_index = True)

MiddlesbroughData['Middlesbrough_Goals'] = MiddlesbroughData['FTHG'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['FTAG'])
MiddlesbroughData['Opponent_Goals'] = MiddlesbroughData['FTHG'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['FTAG'])
MiddlesbroughData['Middlesbrough_Shots'] = MiddlesbroughData['HS'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AS'])
MiddlesbroughData['Opponent_Shots'] = MiddlesbroughData['HS'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AS'])
MiddlesbroughData['Middlesbrough_SoT'] = MiddlesbroughData['HST'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AST'])
MiddlesbroughData['Opponent_SoT'] = MiddlesbroughData['HST'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AST'])
MiddlesbroughData['Middlesbrough_Goals'] = MiddlesbroughData['FTHG'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['FTAG'])
MiddlesbroughData['Opponent_Goals'] = MiddlesbroughData['FTHG'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['FTAG'])
MiddlesbroughData['Middlesbrough_Corners'] = MiddlesbroughData['HC'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AC'])
MiddlesbroughData['Opponent_Corners'] = MiddlesbroughData['HC'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AC'])
MiddlesbroughData['Middlesbrough_Fouls'] = MiddlesbroughData['HF'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AF'])
MiddlesbroughData['Opponent_Fouls'] = MiddlesbroughData['HF'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AF'])
MiddlesbroughData['Middlesbrough_Yellow'] = MiddlesbroughData['HY'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AY'])
MiddlesbroughData['Opponent_Yellow'] = MiddlesbroughData['HY'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AY'])
MiddlesbroughData['Middlesbrough_Red'] = MiddlesbroughData['HR'].where(MiddlesbroughData['HomeTeam'] == 'Middlesbrough', MiddlesbroughData['AR'])
MiddlesbroughData['Opponent_Red'] = MiddlesbroughData['HR'].where(MiddlesbroughData['AwayTeam'] == 'Middlesbrough', MiddlesbroughData['AR'])

conditions = [
    (MiddlesbroughData['FTR'] == 'D'),
    (MiddlesbroughData['FTR'] == 'H') & (MiddlesbroughData['HomeTeam'] == 'Middlesbrough'),
    (MiddlesbroughData['FTR'] == 'A') & (MiddlesbroughData['AwayTeam'] == 'Middlesbrough'),
    (MiddlesbroughData['FTR'] == 'H') & (MiddlesbroughData['AwayTeam'] == 'Middlesbrough'),
    (MiddlesbroughData['FTR'] == 'A') & (MiddlesbroughData['HomeTeam'] == 'Middlesbrough')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

MiddlesbroughData['Middlesbrough Result'] = np.select(conditions, values)


#MiddlesbroughData

# %%
SouthamptonData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Southampton' or row['AwayTeam'] == 'Southampton'):
    #SouthamptonData = SouthamptonData.append(row, ignore_index = True)

SouthamptonData['Southampton_Goals'] = SouthamptonData['FTHG'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['FTAG'])
SouthamptonData['Opponent_Goals'] = SouthamptonData['FTHG'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['FTAG'])
SouthamptonData['Southampton_Shots'] = SouthamptonData['HS'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AS'])
SouthamptonData['Opponent_Shots'] = SouthamptonData['HS'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AS'])
SouthamptonData['Southampton_SoT'] = SouthamptonData['HST'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AST'])
SouthamptonData['Opponent_SoT'] = SouthamptonData['HST'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AST'])
SouthamptonData['Southampton_Goals'] = SouthamptonData['FTHG'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['FTAG'])
SouthamptonData['Opponent_Goals'] = SouthamptonData['FTHG'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['FTAG'])
SouthamptonData['Southampton_Corners'] = SouthamptonData['HC'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AC'])
SouthamptonData['Opponent_Corners'] = SouthamptonData['HC'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AC'])
SouthamptonData['Southampton_Fouls'] = SouthamptonData['HF'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AF'])
SouthamptonData['Opponent_Fouls'] = SouthamptonData['HF'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AF'])
SouthamptonData['Southampton_Yellow'] = SouthamptonData['HY'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AY'])
SouthamptonData['Opponent_Yellow'] = SouthamptonData['HY'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AY'])
SouthamptonData['Southampton_Red'] = SouthamptonData['HR'].where(SouthamptonData['HomeTeam'] == 'Southampton', SouthamptonData['AR'])
SouthamptonData['Opponent_Red'] = SouthamptonData['HR'].where(SouthamptonData['AwayTeam'] == 'Southampton', SouthamptonData['AR'])

conditions = [
    (SouthamptonData['FTR'] == 'D'),
    (SouthamptonData['FTR'] == 'H') & (SouthamptonData['HomeTeam'] == 'Southampton'),
    (SouthamptonData['FTR'] == 'A') & (SouthamptonData['AwayTeam'] == 'Southampton'),
    (SouthamptonData['FTR'] == 'H') & (SouthamptonData['AwayTeam'] == 'Southampton'),
    (SouthamptonData['FTR'] == 'A') & (SouthamptonData['HomeTeam'] == 'Southampton')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

SouthamptonData['Southampton Result'] = np.select(conditions, values)


#SouthamptonData

# %%
ArsenalData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Arsenal' or row['AwayTeam'] == 'Arsenal'):
    #ArsenalData = ArsenalData.append(row, ignore_index = True)

ArsenalData['Arsenal_Goals'] = ArsenalData['FTHG'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['FTAG'])
ArsenalData['Opponent_Goals'] = ArsenalData['FTHG'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['FTAG'])
ArsenalData['Arsenal_Shots'] = ArsenalData['HS'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AS'])
ArsenalData['Opponent_Shots'] = ArsenalData['HS'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AS'])
ArsenalData['Arsenal_SoT'] = ArsenalData['HST'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AST'])
ArsenalData['Opponent_SoT'] = ArsenalData['HST'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AST'])
ArsenalData['Arsenal_Goals'] = ArsenalData['FTHG'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['FTAG'])
ArsenalData['Opponent_Goals'] = ArsenalData['FTHG'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['FTAG'])
ArsenalData['Arsenal_Corners'] = ArsenalData['HC'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AC'])
ArsenalData['Opponent_Corners'] = ArsenalData['HC'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AC'])
ArsenalData['Arsenal_Fouls'] = ArsenalData['HF'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AF'])
ArsenalData['Opponent_Fouls'] = ArsenalData['HF'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AF'])
ArsenalData['Arsenal_Yellow'] = ArsenalData['HY'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AY'])
ArsenalData['Opponent_Yellow'] = ArsenalData['HY'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AY'])
ArsenalData['Arsenal_Red'] = ArsenalData['HR'].where(ArsenalData['HomeTeam'] == 'Arsenal', ArsenalData['AR'])
ArsenalData['Opponent_Red'] = ArsenalData['HR'].where(ArsenalData['AwayTeam'] == 'Arsenal', ArsenalData['AR'])

conditions = [
    (ArsenalData['FTR'] == 'D'),
    (ArsenalData['FTR'] == 'H') & (ArsenalData['HomeTeam'] == 'Arsenal'),
    (ArsenalData['FTR'] == 'A') & (ArsenalData['AwayTeam'] == 'Arsenal'),
    (ArsenalData['FTR'] == 'H') & (ArsenalData['AwayTeam'] == 'Arsenal'),
    (ArsenalData['FTR'] == 'A') & (ArsenalData['HomeTeam'] == 'Arsenal')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

ArsenalData['Arsenal Result'] = np.select(conditions, values)


#ArsenalData

# %%
BournemouthData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Bournemouth' or row['AwayTeam'] == 'Bournemouth'):
    #BournemouthData = BournemouthData.append(row, ignore_index = True)

BournemouthData['Bournemouth_Goals'] = BournemouthData['FTHG'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['FTAG'])
BournemouthData['Opponent_Goals'] = BournemouthData['FTHG'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['FTAG'])
BournemouthData['Bournemouth_Shots'] = BournemouthData['HS'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AS'])
BournemouthData['Opponent_Shots'] = BournemouthData['HS'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AS'])
BournemouthData['Bournemouth_SoT'] = BournemouthData['HST'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AST'])
BournemouthData['Opponent_SoT'] = BournemouthData['HST'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AST'])
BournemouthData['Bournemouth_Goals'] = BournemouthData['FTHG'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['FTAG'])
BournemouthData['Opponent_Goals'] = BournemouthData['FTHG'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['FTAG'])
BournemouthData['Bournemouth_Corners'] = BournemouthData['HC'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AC'])
BournemouthData['Opponent_Corners'] = BournemouthData['HC'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AC'])
BournemouthData['Bournemouth_Fouls'] = BournemouthData['HF'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AF'])
BournemouthData['Opponent_Fouls'] = BournemouthData['HF'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AF'])
BournemouthData['Bournemouth_Yellow'] = BournemouthData['HY'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AY'])
BournemouthData['Opponent_Yellow'] = BournemouthData['HY'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AY'])
BournemouthData['Bournemouth_Red'] = BournemouthData['HR'].where(BournemouthData['HomeTeam'] == 'Bournemouth', BournemouthData['AR'])
BournemouthData['Opponent_Red'] = BournemouthData['HR'].where(BournemouthData['AwayTeam'] == 'Bournemouth', BournemouthData['AR'])

conditions = [
    (BournemouthData['FTR'] == 'D'),
    (BournemouthData['FTR'] == 'H') & (BournemouthData['HomeTeam'] == 'Bournemouth'),
    (BournemouthData['FTR'] == 'A') & (BournemouthData['AwayTeam'] == 'Bournemouth'),
    (BournemouthData['FTR'] == 'H') & (BournemouthData['AwayTeam'] == 'Bournemouth'),
    (BournemouthData['FTR'] == 'A') & (BournemouthData['HomeTeam'] == 'Bournemouth')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

BournemouthData['Bournemouth Result'] = np.select(conditions, values)


#BournemouthData

# %%
ChelseaData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Chelsea' or row['AwayTeam'] == 'Chelsea'):
    #ChelseaData = ChelseaData.append(row, ignore_index = True)

ChelseaData['Chelsea_Goals'] = ChelseaData['FTHG'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['FTAG'])
ChelseaData['Opponent_Goals'] = ChelseaData['FTHG'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['FTAG'])
ChelseaData['Chelsea_Shots'] = ChelseaData['HS'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AS'])
ChelseaData['Opponent_Shots'] = ChelseaData['HS'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AS'])
ChelseaData['Chelsea_SoT'] = ChelseaData['HST'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AST'])
ChelseaData['Opponent_SoT'] = ChelseaData['HST'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AST'])
ChelseaData['Chelsea_Goals'] = ChelseaData['FTHG'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['FTAG'])
ChelseaData['Opponent_Goals'] = ChelseaData['FTHG'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['FTAG'])
ChelseaData['Chelsea_Corners'] = ChelseaData['HC'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AC'])
ChelseaData['Opponent_Corners'] = ChelseaData['HC'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AC'])
ChelseaData['Chelsea_Fouls'] = ChelseaData['HF'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AF'])
ChelseaData['Opponent_Fouls'] = ChelseaData['HF'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AF'])
ChelseaData['Chelsea_Yellow'] = ChelseaData['HY'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AY'])
ChelseaData['Opponent_Yellow'] = ChelseaData['HY'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AY'])
ChelseaData['Chelsea_Red'] = ChelseaData['HR'].where(ChelseaData['HomeTeam'] == 'Chelsea', ChelseaData['AR'])
ChelseaData['Opponent_Red'] = ChelseaData['HR'].where(ChelseaData['AwayTeam'] == 'Chelsea', ChelseaData['AR'])

conditions = [
    (ChelseaData['FTR'] == 'D'),
    (ChelseaData['FTR'] == 'H') & (ChelseaData['HomeTeam'] == 'Chelsea'),
    (ChelseaData['FTR'] == 'A') & (ChelseaData['AwayTeam'] == 'Chelsea'),
    (ChelseaData['FTR'] == 'H') & (ChelseaData['AwayTeam'] == 'Chelsea'),
    (ChelseaData['FTR'] == 'A') & (ChelseaData['HomeTeam'] == 'Chelsea')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

ChelseaData['Chelsea Result'] = np.select(conditions, values)


#ChelseaData

# %%
ManUnitedData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'ManUnited' or row['AwayTeam'] == 'ManUnited'):
    #ManUnitedData = ManUnitedData.append(row, ignore_index = True)

ManUnitedData['ManUnited_Goals'] = ManUnitedData['FTHG'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['FTAG'])
ManUnitedData['Opponent_Goals'] = ManUnitedData['FTHG'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['FTAG'])
ManUnitedData['ManUnited_Shots'] = ManUnitedData['HS'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AS'])
ManUnitedData['Opponent_Shots'] = ManUnitedData['HS'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AS'])
ManUnitedData['ManUnited_SoT'] = ManUnitedData['HST'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AST'])
ManUnitedData['Opponent_SoT'] = ManUnitedData['HST'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AST'])
ManUnitedData['ManUnited_Goals'] = ManUnitedData['FTHG'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['FTAG'])
ManUnitedData['Opponent_Goals'] = ManUnitedData['FTHG'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['FTAG'])
ManUnitedData['ManUnited_Corners'] = ManUnitedData['HC'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AC'])
ManUnitedData['Opponent_Corners'] = ManUnitedData['HC'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AC'])
ManUnitedData['ManUnited_Fouls'] = ManUnitedData['HF'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AF'])
ManUnitedData['Opponent_Fouls'] = ManUnitedData['HF'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AF'])
ManUnitedData['ManUnited_Yellow'] = ManUnitedData['HY'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AY'])
ManUnitedData['Opponent_Yellow'] = ManUnitedData['HY'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AY'])
ManUnitedData['ManUnited_Red'] = ManUnitedData['HR'].where(ManUnitedData['HomeTeam'] == 'ManUnited', ManUnitedData['AR'])
ManUnitedData['Opponent_Red'] = ManUnitedData['HR'].where(ManUnitedData['AwayTeam'] == 'ManUnited', ManUnitedData['AR'])

conditions = [
    (ManUnitedData['FTR'] == 'D'),
    (ManUnitedData['FTR'] == 'H') & (ManUnitedData['HomeTeam'] == 'Man United'),
    (ManUnitedData['FTR'] == 'A') & (ManUnitedData['AwayTeam'] == 'Man United'),
    (ManUnitedData['FTR'] == 'H') & (ManUnitedData['AwayTeam'] == 'Man United'),
    (ManUnitedData['FTR'] == 'A') & (ManUnitedData['HomeTeam'] == 'Man United')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

ManUnitedData['ManUnited Result'] = np.select(conditions, values)


#ManUnitedData

# %%
LeicesterData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Leicester' or row['AwayTeam'] == 'Leicester'):
    #LeicesterData = LeicesterData.append(row, ignore_index = True)

LeicesterData['Leicester_Goals'] = LeicesterData['FTHG'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['FTAG'])
LeicesterData['Opponent_Goals'] = LeicesterData['FTHG'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['FTAG'])
LeicesterData['Leicester_Shots'] = LeicesterData['HS'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AS'])
LeicesterData['Opponent_Shots'] = LeicesterData['HS'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AS'])
LeicesterData['Leicester_SoT'] = LeicesterData['HST'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AST'])
LeicesterData['Opponent_SoT'] = LeicesterData['HST'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AST'])
LeicesterData['Leicester_Goals'] = LeicesterData['FTHG'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['FTAG'])
LeicesterData['Opponent_Goals'] = LeicesterData['FTHG'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['FTAG'])
LeicesterData['Leicester_Corners'] = LeicesterData['HC'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AC'])
LeicesterData['Opponent_Corners'] = LeicesterData['HC'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AC'])
LeicesterData['Leicester_Fouls'] = LeicesterData['HF'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AF'])
LeicesterData['Opponent_Fouls'] = LeicesterData['HF'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AF'])
LeicesterData['Leicester_Yellow'] = LeicesterData['HY'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AY'])
LeicesterData['Opponent_Yellow'] = LeicesterData['HY'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AY'])
LeicesterData['Leicester_Red'] = LeicesterData['HR'].where(LeicesterData['HomeTeam'] == 'Leicester', LeicesterData['AR'])
LeicesterData['Opponent_Red'] = LeicesterData['HR'].where(LeicesterData['AwayTeam'] == 'Leicester', LeicesterData['AR'])

conditions = [
    (LeicesterData['FTR'] == 'D'),
    (LeicesterData['FTR'] == 'H') & (LeicesterData['HomeTeam'] == 'Leicester'),
    (LeicesterData['FTR'] == 'A') & (LeicesterData['AwayTeam'] == 'Leicester'),
    (LeicesterData['FTR'] == 'H') & (LeicesterData['AwayTeam'] == 'Leicester'),
    (LeicesterData['FTR'] == 'A') & (LeicesterData['HomeTeam'] == 'Leicester')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

LeicesterData['Leicester Result'] = np.select(conditions, values)


#LeicesterData

# %%
StokeData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Stoke' or row['AwayTeam'] == 'Stoke'):
    #StokeData = StokeData.append(row, ignore_index = True)

StokeData['Stoke_Goals'] = StokeData['FTHG'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['FTAG'])
StokeData['Opponent_Goals'] = StokeData['FTHG'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['FTAG'])
StokeData['Stoke_Shots'] = StokeData['HS'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AS'])
StokeData['Opponent_Shots'] = StokeData['HS'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AS'])
StokeData['Stoke_SoT'] = StokeData['HST'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AST'])
StokeData['Opponent_SoT'] = StokeData['HST'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AST'])
StokeData['Stoke_Goals'] = StokeData['FTHG'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['FTAG'])
StokeData['Opponent_Goals'] = StokeData['FTHG'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['FTAG'])
StokeData['Stoke_Corners'] = StokeData['HC'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AC'])
StokeData['Opponent_Corners'] = StokeData['HC'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AC'])
StokeData['Stoke_Fouls'] = StokeData['HF'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AF'])
StokeData['Opponent_Fouls'] = StokeData['HF'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AF'])
StokeData['Stoke_Yellow'] = StokeData['HY'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AY'])
StokeData['Opponent_Yellow'] = StokeData['HY'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AY'])
StokeData['Stoke_Red'] = StokeData['HR'].where(StokeData['HomeTeam'] == 'Stoke', StokeData['AR'])
StokeData['Opponent_Red'] = StokeData['HR'].where(StokeData['AwayTeam'] == 'Stoke', StokeData['AR'])

conditions = [
    (StokeData['FTR'] == 'D'),
    (StokeData['FTR'] == 'H') & (StokeData['HomeTeam'] == 'Stoke'),
    (StokeData['FTR'] == 'A') & (StokeData['AwayTeam'] == 'Stoke'),
    (StokeData['FTR'] == 'H') & (StokeData['AwayTeam'] == 'Stoke'),
    (StokeData['FTR'] == 'A') & (StokeData['HomeTeam'] == 'Stoke')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

StokeData['Stoke Result'] = np.select(conditions, values)


#StokeData

# %%
SwanseaData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Swansea' or row['AwayTeam'] == 'Swansea'):
    #SwanseaData = SwanseaData.append(row, ignore_index = True)

SwanseaData['Swansea_Goals'] = SwanseaData['FTHG'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['FTAG'])
SwanseaData['Opponent_Goals'] = SwanseaData['FTHG'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['FTAG'])
SwanseaData['Swansea_Shots'] = SwanseaData['HS'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AS'])
SwanseaData['Opponent_Shots'] = SwanseaData['HS'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AS'])
SwanseaData['Swansea_SoT'] = SwanseaData['HST'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AST'])
SwanseaData['Opponent_SoT'] = SwanseaData['HST'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AST'])
SwanseaData['Swansea_Goals'] = SwanseaData['FTHG'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['FTAG'])
SwanseaData['Opponent_Goals'] = SwanseaData['FTHG'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['FTAG'])
SwanseaData['Swansea_Corners'] = SwanseaData['HC'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AC'])
SwanseaData['Opponent_Corners'] = SwanseaData['HC'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AC'])
SwanseaData['Swansea_Fouls'] = SwanseaData['HF'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AF'])
SwanseaData['Opponent_Fouls'] = SwanseaData['HF'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AF'])
SwanseaData['Swansea_Yellow'] = SwanseaData['HY'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AY'])
SwanseaData['Opponent_Yellow'] = SwanseaData['HY'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AY'])
SwanseaData['Swansea_Red'] = SwanseaData['HR'].where(SwanseaData['HomeTeam'] == 'Swansea', SwanseaData['AR'])
SwanseaData['Opponent_Red'] = SwanseaData['HR'].where(SwanseaData['AwayTeam'] == 'Swansea', SwanseaData['AR'])

conditions = [
    (SwanseaData['FTR'] == 'D'),
    (SwanseaData['FTR'] == 'H') & (SwanseaData['HomeTeam'] == 'Swansea'),
    (SwanseaData['FTR'] == 'A') & (SwanseaData['AwayTeam'] == 'Swansea'),
    (SwanseaData['FTR'] == 'H') & (SwanseaData['AwayTeam'] == 'Swansea'),
    (SwanseaData['FTR'] == 'A') & (SwanseaData['HomeTeam'] == 'Swansea')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

SwanseaData['Swansea Result'] = np.select(conditions, values)


#SwanseaData

# %%
TottenhamData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Tottenham' or row['AwayTeam'] == 'Tottenham'):
    #TottenhamData = TottenhamData.append(row, ignore_index = True)

TottenhamData['Tottenham_Goals'] = TottenhamData['FTHG'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['FTAG'])
TottenhamData['Opponent_Goals'] = TottenhamData['FTHG'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['FTAG'])
TottenhamData['Tottenham_Shots'] = TottenhamData['HS'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AS'])
TottenhamData['Opponent_Shots'] = TottenhamData['HS'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AS'])
TottenhamData['Tottenham_SoT'] = TottenhamData['HST'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AST'])
TottenhamData['Opponent_SoT'] = TottenhamData['HST'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AST'])
TottenhamData['Tottenham_Goals'] = TottenhamData['FTHG'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['FTAG'])
TottenhamData['Opponent_Goals'] = TottenhamData['FTHG'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['FTAG'])
TottenhamData['Tottenham_Corners'] = TottenhamData['HC'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AC'])
TottenhamData['Opponent_Corners'] = TottenhamData['HC'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AC'])
TottenhamData['Tottenham_Fouls'] = TottenhamData['HF'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AF'])
TottenhamData['Opponent_Fouls'] = TottenhamData['HF'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AF'])
TottenhamData['Tottenham_Yellow'] = TottenhamData['HY'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AY'])
TottenhamData['Opponent_Yellow'] = TottenhamData['HY'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AY'])
TottenhamData['Tottenham_Red'] = TottenhamData['HR'].where(TottenhamData['HomeTeam'] == 'Tottenham', TottenhamData['AR'])
TottenhamData['Opponent_Red'] = TottenhamData['HR'].where(TottenhamData['AwayTeam'] == 'Tottenham', TottenhamData['AR'])

conditions = [
    (TottenhamData['FTR'] == 'D'),
    (TottenhamData['FTR'] == 'H') & (TottenhamData['HomeTeam'] == 'Tottenham'),
    (TottenhamData['FTR'] == 'A') & (TottenhamData['AwayTeam'] == 'Tottenham'),
    (TottenhamData['FTR'] == 'H') & (TottenhamData['AwayTeam'] == 'Tottenham'),
    (TottenhamData['FTR'] == 'A') & (TottenhamData['HomeTeam'] == 'Tottenham')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

TottenhamData['Tottenham Result'] = np.select(conditions, values)


#TottenhamData

# %%
WatfordData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Watford' or row['AwayTeam'] == 'Watford'):
    #WatfordData = WatfordData.append(row, ignore_index = True)

WatfordData['Watford_Goals'] = WatfordData['FTHG'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['FTAG'])
WatfordData['Opponent_Goals'] = WatfordData['FTHG'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['FTAG'])
WatfordData['Watford_Shots'] = WatfordData['HS'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AS'])
WatfordData['Opponent_Shots'] = WatfordData['HS'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AS'])
WatfordData['Watford_SoT'] = WatfordData['HST'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AST'])
WatfordData['Opponent_SoT'] = WatfordData['HST'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AST'])
WatfordData['Watford_Goals'] = WatfordData['FTHG'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['FTAG'])
WatfordData['Opponent_Goals'] = WatfordData['FTHG'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['FTAG'])
WatfordData['Watford_Corners'] = WatfordData['HC'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AC'])
WatfordData['Opponent_Corners'] = WatfordData['HC'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AC'])
WatfordData['Watford_Fouls'] = WatfordData['HF'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AF'])
WatfordData['Opponent_Fouls'] = WatfordData['HF'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AF'])
WatfordData['Watford_Yellow'] = WatfordData['HY'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AY'])
WatfordData['Opponent_Yellow'] = WatfordData['HY'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AY'])
WatfordData['Watford_Red'] = WatfordData['HR'].where(WatfordData['HomeTeam'] == 'Watford', WatfordData['AR'])
WatfordData['Opponent_Red'] = WatfordData['HR'].where(WatfordData['AwayTeam'] == 'Watford', WatfordData['AR'])

conditions = [
    (WatfordData['FTR'] == 'D'),
    (WatfordData['FTR'] == 'H') & (WatfordData['HomeTeam'] == 'Watford'),
    (WatfordData['FTR'] == 'A') & (WatfordData['AwayTeam'] == 'Watford'),
    (WatfordData['FTR'] == 'H') & (WatfordData['AwayTeam'] == 'Watford'),
    (WatfordData['FTR'] == 'A') & (WatfordData['HomeTeam'] == 'Watford')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

WatfordData['Watford Result'] = np.select(conditions, values)


#WatfordData

# %%
WestBromData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'WestBrom' or row['AwayTeam'] == 'WestBrom'):
    #WestBromData = WestBromData.append(row, ignore_index = True)

WestBromData['WestBrom_Goals'] = WestBromData['FTHG'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['FTAG'])
WestBromData['Opponent_Goals'] = WestBromData['FTHG'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['FTAG'])
WestBromData['WestBrom_Shots'] = WestBromData['HS'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AS'])
WestBromData['Opponent_Shots'] = WestBromData['HS'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AS'])
WestBromData['WestBrom_SoT'] = WestBromData['HST'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AST'])
WestBromData['Opponent_SoT'] = WestBromData['HST'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AST'])
WestBromData['WestBrom_Goals'] = WestBromData['FTHG'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['FTAG'])
WestBromData['Opponent_Goals'] = WestBromData['FTHG'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['FTAG'])
WestBromData['WestBrom_Corners'] = WestBromData['HC'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AC'])
WestBromData['Opponent_Corners'] = WestBromData['HC'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AC'])
WestBromData['WestBrom_Fouls'] = WestBromData['HF'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AF'])
WestBromData['Opponent_Fouls'] = WestBromData['HF'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AF'])
WestBromData['WestBrom_Yellow'] = WestBromData['HY'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AY'])
WestBromData['Opponent_Yellow'] = WestBromData['HY'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AY'])
WestBromData['WestBrom_Red'] = WestBromData['HR'].where(WestBromData['HomeTeam'] == 'WestBrom', WestBromData['AR'])
WestBromData['Opponent_Red'] = WestBromData['HR'].where(WestBromData['AwayTeam'] == 'WestBrom', WestBromData['AR'])

conditions = [
    (WestBromData['FTR'] == 'D'),
    (WestBromData['FTR'] == 'H') & (WestBromData['HomeTeam'] == 'West Brom'),
    (WestBromData['FTR'] == 'A') & (WestBromData['AwayTeam'] == 'West Brom'),
    (WestBromData['FTR'] == 'H') & (WestBromData['AwayTeam'] == 'West Brom'),
    (WestBromData['FTR'] == 'A') & (WestBromData['HomeTeam'] == 'West Brom')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

WestBromData['WestBrom Result'] = np.select(conditions, values)


#WestBromData

# %%
SunderlandData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Sunderland' or row['AwayTeam'] == 'Sunderland'):
    #SunderlandData = SunderlandData.append(row, ignore_index = True)

SunderlandData['Sunderland_Goals'] = SunderlandData['FTHG'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['FTAG'])
SunderlandData['Opponent_Goals'] = SunderlandData['FTHG'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['FTAG'])
SunderlandData['Sunderland_Shots'] = SunderlandData['HS'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AS'])
SunderlandData['Opponent_Shots'] = SunderlandData['HS'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AS'])
SunderlandData['Sunderland_SoT'] = SunderlandData['HST'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AST'])
SunderlandData['Opponent_SoT'] = SunderlandData['HST'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AST'])
SunderlandData['Sunderland_Goals'] = SunderlandData['FTHG'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['FTAG'])
SunderlandData['Opponent_Goals'] = SunderlandData['FTHG'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['FTAG'])
SunderlandData['Sunderland_Corners'] = SunderlandData['HC'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AC'])
SunderlandData['Opponent_Corners'] = SunderlandData['HC'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AC'])
SunderlandData['Sunderland_Fouls'] = SunderlandData['HF'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AF'])
SunderlandData['Opponent_Fouls'] = SunderlandData['HF'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AF'])
SunderlandData['Sunderland_Yellow'] = SunderlandData['HY'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AY'])
SunderlandData['Opponent_Yellow'] = SunderlandData['HY'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AY'])
SunderlandData['Sunderland_Red'] = SunderlandData['HR'].where(SunderlandData['HomeTeam'] == 'Sunderland', SunderlandData['AR'])
SunderlandData['Opponent_Red'] = SunderlandData['HR'].where(SunderlandData['AwayTeam'] == 'Sunderland', SunderlandData['AR'])

conditions = [
    (SunderlandData['FTR'] == 'D'),
    (SunderlandData['FTR'] == 'H') & (SunderlandData['HomeTeam'] == 'Sunderland'),
    (SunderlandData['FTR'] == 'A') & (SunderlandData['AwayTeam'] == 'Sunderland'),
    (SunderlandData['FTR'] == 'H') & (SunderlandData['AwayTeam'] == 'Sunderland'),
    (SunderlandData['FTR'] == 'A') & (SunderlandData['HomeTeam'] == 'Sunderland')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

SunderlandData['Sunderland Result'] = np.select(conditions, values)


#SunderlandData

# %%
WestHamData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'WestHam' or row['AwayTeam'] == 'WestHam'):
    #WestHamData = WestHamData.append(row, ignore_index = True)

WestHamData['WestHam_Goals'] = WestHamData['FTHG'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['FTAG'])
WestHamData['Opponent_Goals'] = WestHamData['FTHG'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['FTAG'])
WestHamData['WestHam_Shots'] = WestHamData['HS'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AS'])
WestHamData['Opponent_Shots'] = WestHamData['HS'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AS'])
WestHamData['WestHam_SoT'] = WestHamData['HST'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AST'])
WestHamData['Opponent_SoT'] = WestHamData['HST'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AST'])
WestHamData['WestHam_Goals'] = WestHamData['FTHG'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['FTAG'])
WestHamData['Opponent_Goals'] = WestHamData['FTHG'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['FTAG'])
WestHamData['WestHam_Corners'] = WestHamData['HC'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AC'])
WestHamData['Opponent_Corners'] = WestHamData['HC'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AC'])
WestHamData['WestHam_Fouls'] = WestHamData['HF'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AF'])
WestHamData['Opponent_Fouls'] = WestHamData['HF'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AF'])
WestHamData['WestHam_Yellow'] = WestHamData['HY'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AY'])
WestHamData['Opponent_Yellow'] = WestHamData['HY'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AY'])
WestHamData['WestHam_Red'] = WestHamData['HR'].where(WestHamData['HomeTeam'] == 'WestHam', WestHamData['AR'])
WestHamData['Opponent_Red'] = WestHamData['HR'].where(WestHamData['AwayTeam'] == 'WestHam', WestHamData['AR'])

conditions = [
    (WestHamData['FTR'] == 'D'),
    (WestHamData['FTR'] == 'H') & (WestHamData['HomeTeam'] == 'West Ham'),
    (WestHamData['FTR'] == 'A') & (WestHamData['AwayTeam'] == 'West Ham'),
    (WestHamData['FTR'] == 'H') & (WestHamData['AwayTeam'] == 'West Ham'),
    (WestHamData['FTR'] == 'A') & (WestHamData['HomeTeam'] == 'West Ham')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

WestHamData['WestHam Result'] = np.select(conditions, values)


#WestHamData

# %%
LiverpoolData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Liverpool' or row['AwayTeam'] == 'Liverpool'):
    #LiverpoolData = LiverpoolData.append(row, ignore_index = True)

LiverpoolData['Liverpool_Goals'] = LiverpoolData['FTHG'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['FTAG'])
LiverpoolData['Opponent_Goals'] = LiverpoolData['FTHG'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['FTAG'])
LiverpoolData['Liverpool_Shots'] = LiverpoolData['HS'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AS'])
LiverpoolData['Opponent_Shots'] = LiverpoolData['HS'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AS'])
LiverpoolData['Liverpool_SoT'] = LiverpoolData['HST'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AST'])
LiverpoolData['Opponent_SoT'] = LiverpoolData['HST'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AST'])
LiverpoolData['Liverpool_Goals'] = LiverpoolData['FTHG'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['FTAG'])
LiverpoolData['Opponent_Goals'] = LiverpoolData['FTHG'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['FTAG'])
LiverpoolData['Liverpool_Corners'] = LiverpoolData['HC'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AC'])
LiverpoolData['Opponent_Corners'] = LiverpoolData['HC'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AC'])
LiverpoolData['Liverpool_Fouls'] = LiverpoolData['HF'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AF'])
LiverpoolData['Opponent_Fouls'] = LiverpoolData['HF'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AF'])
LiverpoolData['Liverpool_Yellow'] = LiverpoolData['HY'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AY'])
LiverpoolData['Opponent_Yellow'] = LiverpoolData['HY'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AY'])
LiverpoolData['Liverpool_Red'] = LiverpoolData['HR'].where(LiverpoolData['HomeTeam'] == 'Liverpool', LiverpoolData['AR'])
LiverpoolData['Opponent_Red'] = LiverpoolData['HR'].where(LiverpoolData['AwayTeam'] == 'Liverpool', LiverpoolData['AR'])

conditions = [
    (LiverpoolData['FTR'] == 'D'),
    (LiverpoolData['FTR'] == 'H') & (LiverpoolData['HomeTeam'] == 'Liverpool'),
    (LiverpoolData['FTR'] == 'A') & (LiverpoolData['AwayTeam'] == 'Liverpool'),
    (LiverpoolData['FTR'] == 'H') & (LiverpoolData['AwayTeam'] == 'Liverpool'),
    (LiverpoolData['FTR'] == 'A') & (LiverpoolData['HomeTeam'] == 'Liverpool')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

LiverpoolData['Liverpool Result'] = np.select(conditions, values)


#LiverpoolData

# %%
BrightonData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Brighton' or row['AwayTeam'] == 'Brighton'):
    #BrightonData = BrightonData.append(row, ignore_index = True)

BrightonData['Brighton_Goals'] = BrightonData['FTHG'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['FTAG'])
BrightonData['Opponent_Goals'] = BrightonData['FTHG'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['FTAG'])
BrightonData['Brighton_Shots'] = BrightonData['HS'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AS'])
BrightonData['Opponent_Shots'] = BrightonData['HS'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AS'])
BrightonData['Brighton_SoT'] = BrightonData['HST'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AST'])
BrightonData['Opponent_SoT'] = BrightonData['HST'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AST'])
BrightonData['Brighton_Goals'] = BrightonData['FTHG'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['FTAG'])
BrightonData['Opponent_Goals'] = BrightonData['FTHG'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['FTAG'])
BrightonData['Brighton_Corners'] = BrightonData['HC'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AC'])
BrightonData['Opponent_Corners'] = BrightonData['HC'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AC'])
BrightonData['Brighton_Fouls'] = BrightonData['HF'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AF'])
BrightonData['Opponent_Fouls'] = BrightonData['HF'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AF'])
BrightonData['Brighton_Yellow'] = BrightonData['HY'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AY'])
BrightonData['Opponent_Yellow'] = BrightonData['HY'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AY'])
BrightonData['Brighton_Red'] = BrightonData['HR'].where(BrightonData['HomeTeam'] == 'Brighton', BrightonData['AR'])
BrightonData['Opponent_Red'] = BrightonData['HR'].where(BrightonData['AwayTeam'] == 'Brighton', BrightonData['AR'])

conditions = [
    (BrightonData['FTR'] == 'D'),
    (BrightonData['FTR'] == 'H') & (BrightonData['HomeTeam'] == 'Brighton'),
    (BrightonData['FTR'] == 'A') & (BrightonData['AwayTeam'] == 'Brighton'),
    (BrightonData['FTR'] == 'H') & (BrightonData['AwayTeam'] == 'Brighton'),
    (BrightonData['FTR'] == 'A') & (BrightonData['HomeTeam'] == 'Brighton')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

BrightonData['Brighton Result'] = np.select(conditions, values)


#BrightonData

# %%
NewcastleData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Newcastle' or row['AwayTeam'] == 'Newcastle'):
    #NewcastleData = NewcastleData.append(row, ignore_index = True)

NewcastleData['Newcastle_Goals'] = NewcastleData['FTHG'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['FTAG'])
NewcastleData['Opponent_Goals'] = NewcastleData['FTHG'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['FTAG'])
NewcastleData['Newcastle_Shots'] = NewcastleData['HS'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AS'])
NewcastleData['Opponent_Shots'] = NewcastleData['HS'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AS'])
NewcastleData['Newcastle_SoT'] = NewcastleData['HST'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AST'])
NewcastleData['Opponent_SoT'] = NewcastleData['HST'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AST'])
NewcastleData['Newcastle_Goals'] = NewcastleData['FTHG'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['FTAG'])
NewcastleData['Opponent_Goals'] = NewcastleData['FTHG'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['FTAG'])
NewcastleData['Newcastle_Corners'] = NewcastleData['HC'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AC'])
NewcastleData['Opponent_Corners'] = NewcastleData['HC'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AC'])
NewcastleData['Newcastle_Fouls'] = NewcastleData['HF'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AF'])
NewcastleData['Opponent_Fouls'] = NewcastleData['HF'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AF'])
NewcastleData['Newcastle_Yellow'] = NewcastleData['HY'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AY'])
NewcastleData['Opponent_Yellow'] = NewcastleData['HY'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AY'])
NewcastleData['Newcastle_Red'] = NewcastleData['HR'].where(NewcastleData['HomeTeam'] == 'Newcastle', NewcastleData['AR'])
NewcastleData['Opponent_Red'] = NewcastleData['HR'].where(NewcastleData['AwayTeam'] == 'Newcastle', NewcastleData['AR'])

conditions = [
    (NewcastleData['FTR'] == 'D'),
    (NewcastleData['FTR'] == 'H') & (NewcastleData['HomeTeam'] == 'Newcastle'),
    (NewcastleData['FTR'] == 'A') & (NewcastleData['AwayTeam'] == 'Newcastle'),
    (NewcastleData['FTR'] == 'H') & (NewcastleData['AwayTeam'] == 'Newcastle'),
    (NewcastleData['FTR'] == 'A') & (NewcastleData['HomeTeam'] == 'Newcastle')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

NewcastleData['Newcastle Result'] = np.select(conditions, values)


#NewcastleData

# %%
HuddersfieldData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Huddersfield' or row['AwayTeam'] == 'Huddersfield'):
    #HuddersfieldData = HuddersfieldData.append(row, ignore_index = True)

HuddersfieldData['Huddersfield_Goals'] = HuddersfieldData['FTHG'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['FTAG'])
HuddersfieldData['Opponent_Goals'] = HuddersfieldData['FTHG'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['FTAG'])
HuddersfieldData['Huddersfield_Shots'] = HuddersfieldData['HS'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AS'])
HuddersfieldData['Opponent_Shots'] = HuddersfieldData['HS'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AS'])
HuddersfieldData['Huddersfield_SoT'] = HuddersfieldData['HST'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AST'])
HuddersfieldData['Opponent_SoT'] = HuddersfieldData['HST'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AST'])
HuddersfieldData['Huddersfield_Goals'] = HuddersfieldData['FTHG'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['FTAG'])
HuddersfieldData['Opponent_Goals'] = HuddersfieldData['FTHG'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['FTAG'])
HuddersfieldData['Huddersfield_Corners'] = HuddersfieldData['HC'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AC'])
HuddersfieldData['Opponent_Corners'] = HuddersfieldData['HC'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AC'])
HuddersfieldData['Huddersfield_Fouls'] = HuddersfieldData['HF'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AF'])
HuddersfieldData['Opponent_Fouls'] = HuddersfieldData['HF'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AF'])
HuddersfieldData['Huddersfield_Yellow'] = HuddersfieldData['HY'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AY'])
HuddersfieldData['Opponent_Yellow'] = HuddersfieldData['HY'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AY'])
HuddersfieldData['Huddersfield_Red'] = HuddersfieldData['HR'].where(HuddersfieldData['HomeTeam'] == 'Huddersfield', HuddersfieldData['AR'])
HuddersfieldData['Opponent_Red'] = HuddersfieldData['HR'].where(HuddersfieldData['AwayTeam'] == 'Huddersfield', HuddersfieldData['AR'])

conditions = [
    (HuddersfieldData['FTR'] == 'D'),
    (HuddersfieldData['FTR'] == 'H') & (HuddersfieldData['HomeTeam'] == 'Huddersfield'),
    (HuddersfieldData['FTR'] == 'A') & (HuddersfieldData['AwayTeam'] == 'Huddersfield'),
    (HuddersfieldData['FTR'] == 'H') & (HuddersfieldData['AwayTeam'] == 'Huddersfield'),
    (HuddersfieldData['FTR'] == 'A') & (HuddersfieldData['HomeTeam'] == 'Huddersfield')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

HuddersfieldData['Huddersfield Result'] = np.select(conditions, values)


#HuddersfieldData

# %%
FulhamData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Fulham' or row['AwayTeam'] == 'Fulham'):
    #FulhamData = FulhamData.append(row, ignore_index = True)

FulhamData['Fulham_Goals'] = FulhamData['FTHG'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['FTAG'])
FulhamData['Opponent_Goals'] = FulhamData['FTHG'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['FTAG'])
FulhamData['Fulham_Shots'] = FulhamData['HS'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AS'])
FulhamData['Opponent_Shots'] = FulhamData['HS'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AS'])
FulhamData['Fulham_SoT'] = FulhamData['HST'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AST'])
FulhamData['Opponent_SoT'] = FulhamData['HST'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AST'])
FulhamData['Fulham_Goals'] = FulhamData['FTHG'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['FTAG'])
FulhamData['Opponent_Goals'] = FulhamData['FTHG'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['FTAG'])
FulhamData['Fulham_Corners'] = FulhamData['HC'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AC'])
FulhamData['Opponent_Corners'] = FulhamData['HC'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AC'])
FulhamData['Fulham_Fouls'] = FulhamData['HF'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AF'])
FulhamData['Opponent_Fouls'] = FulhamData['HF'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AF'])
FulhamData['Fulham_Yellow'] = FulhamData['HY'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AY'])
FulhamData['Opponent_Yellow'] = FulhamData['HY'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AY'])
FulhamData['Fulham_Red'] = FulhamData['HR'].where(FulhamData['HomeTeam'] == 'Fulham', FulhamData['AR'])
FulhamData['Opponent_Red'] = FulhamData['HR'].where(FulhamData['AwayTeam'] == 'Fulham', FulhamData['AR'])

conditions = [
    (FulhamData['FTR'] == 'D'),
    (FulhamData['FTR'] == 'H') & (FulhamData['HomeTeam'] == 'Fulham'),
    (FulhamData['FTR'] == 'A') & (FulhamData['AwayTeam'] == 'Fulham'),
    (FulhamData['FTR'] == 'H') & (FulhamData['AwayTeam'] == 'Fulham'),
    (FulhamData['FTR'] == 'A') & (FulhamData['HomeTeam'] == 'Fulham')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

FulhamData['Fulham Result'] = np.select(conditions, values)


#FulhamData

# %%
WolvesData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Wolves' or row['AwayTeam'] == 'Wolves'):
    #WolvesData = WolvesData.append(row, ignore_index = True)

WolvesData['Wolves_Goals'] = WolvesData['FTHG'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['FTAG'])
WolvesData['Opponent_Goals'] = WolvesData['FTHG'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['FTAG'])
WolvesData['Wolves_Shots'] = WolvesData['HS'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AS'])
WolvesData['Opponent_Shots'] = WolvesData['HS'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AS'])
WolvesData['Wolves_SoT'] = WolvesData['HST'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AST'])
WolvesData['Opponent_SoT'] = WolvesData['HST'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AST'])
WolvesData['Wolves_Goals'] = WolvesData['FTHG'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['FTAG'])
WolvesData['Opponent_Goals'] = WolvesData['FTHG'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['FTAG'])
WolvesData['Wolves_Corners'] = WolvesData['HC'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AC'])
WolvesData['Opponent_Corners'] = WolvesData['HC'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AC'])
WolvesData['Wolves_Fouls'] = WolvesData['HF'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AF'])
WolvesData['Opponent_Fouls'] = WolvesData['HF'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AF'])
WolvesData['Wolves_Yellow'] = WolvesData['HY'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AY'])
WolvesData['Opponent_Yellow'] = WolvesData['HY'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AY'])
WolvesData['Wolves_Red'] = WolvesData['HR'].where(WolvesData['HomeTeam'] == 'Wolves', WolvesData['AR'])
WolvesData['Opponent_Red'] = WolvesData['HR'].where(WolvesData['AwayTeam'] == 'Wolves', WolvesData['AR'])

conditions = [
    (WolvesData['FTR'] == 'D'),
    (WolvesData['FTR'] == 'H') & (WolvesData['HomeTeam'] == 'Wolves'),
    (WolvesData['FTR'] == 'A') & (WolvesData['AwayTeam'] == 'Wolves'),
    (WolvesData['FTR'] == 'H') & (WolvesData['AwayTeam'] == 'Wolves'),
    (WolvesData['FTR'] == 'A') & (WolvesData['HomeTeam'] == 'Wolves')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

WolvesData['Wolves Result'] = np.select(conditions, values)


#WolvesData

# %%
CardiffData
#for index, row in alldata.iterrows():
  #if(row['HomeTeam'] == 'Cardiff' or row['AwayTeam'] == 'Cardiff'):
    #CardiffData = CardiffData.append(row, ignore_index = True)

CardiffData['Cardiff_Goals'] = CardiffData['FTHG'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['FTAG'])
CardiffData['Opponent_Goals'] = CardiffData['FTHG'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['FTAG'])
CardiffData['Cardiff_Shots'] = CardiffData['HS'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AS'])
CardiffData['Opponent_Shots'] = CardiffData['HS'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AS'])
CardiffData['Cardiff_SoT'] = CardiffData['HST'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AST'])
CardiffData['Opponent_SoT'] = CardiffData['HST'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AST'])
CardiffData['Cardiff_Goals'] = CardiffData['FTHG'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['FTAG'])
CardiffData['Opponent_Goals'] = CardiffData['FTHG'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['FTAG'])
CardiffData['Cardiff_Corners'] = CardiffData['HC'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AC'])
CardiffData['Opponent_Corners'] = CardiffData['HC'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AC'])
CardiffData['Cardiff_Fouls'] = CardiffData['HF'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AF'])
CardiffData['Opponent_Fouls'] = CardiffData['HF'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AF'])
CardiffData['Cardiff_Yellow'] = CardiffData['HY'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AY'])
CardiffData['Opponent_Yellow'] = CardiffData['HY'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AY'])
CardiffData['Cardiff_Red'] = CardiffData['HR'].where(CardiffData['HomeTeam'] == 'Cardiff', CardiffData['AR'])
CardiffData['Opponent_Red'] = CardiffData['HR'].where(CardiffData['AwayTeam'] == 'Cardiff', CardiffData['AR'])

conditions = [
    (CardiffData['FTR'] == 'D'),
    (CardiffData['FTR'] == 'H') & (CardiffData['HomeTeam'] == 'Cardiff'),
    (CardiffData['FTR'] == 'A') & (CardiffData['AwayTeam'] == 'Cardiff'),
    (CardiffData['FTR'] == 'H') & (CardiffData['AwayTeam'] == 'Cardiff'),
    (CardiffData['FTR'] == 'A') & (CardiffData['HomeTeam'] == 'Cardiff')
]

values = ['Draw', 'Win', 'Win', 'Loss', 'Loss']

CardiffData['Cardiff Result'] = np.select(conditions, values)


#CardiffData

# %% [markdown]
# # Data transfered back to drive

# %%
#Do not execute more than once
## Sends data to my Drive
BurnleyData.to_csv('drive/My Drive/EPLData/BurnleyData.csv')
CrystalPalaceData.to_csv('drive/My Drive/EPLData/CrystalPalaceData.csv')
EvertonData.to_csv('drive/My Drive/EPLData/EvertonData.csv')
HullData.to_csv('drive/My Drive/EPLData/HullData.csv')
ManCityData.to_csv('drive/My Drive/EPLData/ManCityData.csv')
MiddlesbroughData.to_csv('drive/My Drive/EPLData/MiddlesbroughData.csv')
SouthamptonData.to_csv('drive/My Drive/EPLData/SouthamptonData.csv')
ArsenalData.to_csv('drive/My Drive/EPLData/ArsenalData.csv')
BournemouthData.to_csv('drive/My Drive/EPLData/BournemouthData.csv')
ChelseaData.to_csv('drive/My Drive/EPLData/ChelseaData.csv')
ManUnitedData.to_csv('drive/My Drive/EPLData/ManUnitedData.csv')
LeicesterData.to_csv('drive/My Drive/EPLData/LeicesterData.csv')
StokeData.to_csv('drive/My Drive/EPLData/StokeData.csv')
SwanseaData.to_csv('drive/My Drive/EPLData/SwanseaData.csv')
TottenhamData.to_csv('drive/My Drive/EPLData/TottenhamData.csv')
WatfordData.to_csv('drive/My Drive/EPLData/WatfordData.csv')
WestBromData.to_csv('drive/My Drive/EPLData/WestBromData.csv')
SunderlandData.to_csv('drive/My Drive/EPLData/SunderlandData.csv')
WestHamData.to_csv('drive/My Drive/EPLData/WestHamData.csv')
LiverpoolData.to_csv('drive/My Drive/EPLData/LiverpoolData.csv')
BrightonData.to_csv('drive/My Drive/EPLData/BrightonData.csv')
NewcastleData.to_csv('drive/My Drive/EPLData/NewcastleData.csv')
HuddersfieldData.to_csv('drive/My Drive/EPLData/HuddersfieldData.csv')
FulhamData.to_csv('drive/My Drive/EPLData/FulhamData.csv')
WolvesData.to_csv('drive/My Drive/EPLData/WolvesData.csv')
CardiffData.to_csv('drive/My Drive/EPLData/CardiffData.csv')

# %% [markdown]
# # Find Best and Worst teams

# %%
alldata

# %%
teams = ['Burnley', 'Crystal Palace', 'Everton', 'Hull', 'Man City',
        'Middlesbrough', 'Southampton', 'Arsenal', 'Bournemouth',
        'Chelsea', 'Man United', 'Leicester', 'Stoke', 'Swansea',
        'Tottenham', 'Watford', 'West Brom', 'Sunderland', 'West Ham',
        'Liverpool', 'Brighton', 'Newcastle', 'Huddersfield', 'Fulham',
        'Wolves', 'Cardiff']
teams

# %%
TeamPPG = {}

# %%
WolvesGames = 0
WolvesPoints = 0
for index, row in WolvesData.iterrows():
  #print(row['Wolves Result'])
  WolvesGames += 1
  if row['Wolves Result'] == 'Win':
    WolvesPoints += 3
  elif row['Wolves Result'] == 'Draw':
    WolvesPoints +=1
print(WolvesGames, WolvesPoints)
WolvesPointsPerGame = WolvesPoints/WolvesGames
print(WolvesPointsPerGame)
TeamPPG['Wolves'] = WolvesPointsPerGame
# Out:
# 38 57
# 1.5

# %%
FulhamGames = 0
FulhamPoints = 0
for index, row in FulhamData.iterrows():
  #print(row['Fulham Result'])
  FulhamGames += 1
  if row['Fulham Result'] == 'Win':
    FulhamPoints += 3
  elif row['Fulham Result'] == 'Draw':
    FulhamPoints +=1
print(FulhamGames, FulhamPoints)
FulhamPointsPerGame = FulhamPoints/FulhamGames
print(FulhamPointsPerGame)
TeamPPG['Fulham'] = FulhamPointsPerGame
# Out:
# 38 26
# 0.6842105263157895

# %%
HuddersfieldGames = 0
HuddersfieldPoints = 0
for index, row in HuddersfieldData.iterrows():
  #print(row['Huddersfield Result'])
  HuddersfieldGames += 1
  if row['Huddersfield Result'] == 'Win':
    HuddersfieldPoints += 3
  elif row['Huddersfield Result'] == 'Draw':
    HuddersfieldPoints +=1
print(HuddersfieldGames, HuddersfieldPoints)
HuddersfieldPointsPerGame = HuddersfieldPoints/HuddersfieldGames
print(HuddersfieldPointsPerGame)
TeamPPG['Huddersfield'] = HuddersfieldPointsPerGame
# Out:
# 76 53
# 0.6973684210526315

# %%
NewcastleGames = 0
NewcastlePoints = 0
for index, row in NewcastleData.iterrows():
  #print(row['Newcastle Result'])
  NewcastleGames += 1
  if row['Newcastle Result'] == 'Win':
    NewcastlePoints += 3
  elif row['Newcastle Result'] == 'Draw':
    NewcastlePoints +=1
print(NewcastleGames, NewcastlePoints)
NewcastlePointsPerGame = NewcastlePoints/NewcastleGames
print(NewcastlePointsPerGame)
TeamPPG['Newcastle'] = NewcastlePointsPerGame
# Out:
# 76 89
# 1.1710526315789473

# %%
BrightonGames = 0
BrightonPoints = 0
for index, row in BrightonData.iterrows():
  #print(row['Brighton Result'])
  BrightonGames += 1
  if row['Brighton Result'] == 'Win':
    BrightonPoints += 3
  elif row['Brighton Result'] == 'Draw':
    BrightonPoints +=1
print(BrightonGames, BrightonPoints)
BrightonPointsPerGame = BrightonPoints/BrightonGames
print(BrightonPointsPerGame)
TeamPPG['Brighton'] = BrightonPointsPerGame
# Out:
# 76 76
# 1.0

# %%
LiverpoolGames = 0
LiverpoolPoints = 0
for index, row in LiverpoolData.iterrows():
  #print(row['Liverpool Result'])
  LiverpoolGames += 1
  if row['Liverpool Result'] == 'Win':
    LiverpoolPoints += 3
  elif row['Liverpool Result'] == 'Draw':
    LiverpoolPoints +=1
print(LiverpoolGames, LiverpoolPoints)
LiverpoolPointsPerGame = LiverpoolPoints/LiverpoolGames
print(LiverpoolPointsPerGame)
TeamPPG['Liverpool'] = LiverpoolPointsPerGame
# Out:
# 114 248
# 2.175438596491228

# %%
WestHamGames = 0
WestHamPoints = 0
for index, row in WestHamData.iterrows():
  #print(row['WestHam Result'])
  WestHamGames += 1
  if row['WestHam Result'] == 'Win':
    WestHamPoints += 3
  elif row['WestHam Result'] == 'Draw':
    WestHamPoints +=1
print(WestHamGames, WestHamPoints)
WestHamPointsPerGame = WestHamPoints/WestHamGames
print(WestHamPointsPerGame)
TeamPPG['WestHam'] = WestHamPointsPerGame
# Out:
# 114 139
# 1.219298245614035

# %%
SunderlandGames = 0
SunderlandPoints = 0
for index, row in SunderlandData.iterrows():
  #print(row['Sunderland Result'])
  SunderlandGames += 1
  if row['Sunderland Result'] == 'Win':
    SunderlandPoints += 3
  elif row['Sunderland Result'] == 'Draw':
    SunderlandPoints +=1
print(SunderlandGames, SunderlandPoints)
SunderlandPointsPerGame = SunderlandPoints/SunderlandGames
print(SunderlandPointsPerGame)
TeamPPG['Sunderland'] = SunderlandPointsPerGame
# Out:
# 38 24
# 0.631578947368421

# %%
WestBromGames = 0
WestBromPoints = 0
for index, row in WestBromData.iterrows():
  #print(row['WestBrom Result'])
  WestBromGames += 1
  if row['WestBrom Result'] == 'Win':
    WestBromPoints += 3
  elif row['WestBrom Result'] == 'Draw':
    WestBromPoints +=1
print(WestBromGames, WestBromPoints)
WestBromPointsPerGame = WestBromPoints/WestBromGames
print(WestBromPointsPerGame)
TeamPPG['WestBrom'] = WestBromPointsPerGame
# Out:
# 76 76
# 1.0

# %%
WatfordGames = 0
WatfordPoints = 0
for index, row in WatfordData.iterrows():
  #print(row['Watford Result'])
  WatfordGames += 1
  if row['Watford Result'] == 'Win':
    WatfordPoints += 3
  elif row['Watford Result'] == 'Draw':
    WatfordPoints +=1
print(WatfordGames, WatfordPoints)
WatfordPointsPerGame = WatfordPoints/WatfordGames
print(WatfordPointsPerGame)
TeamPPG['Watford'] = WatfordPointsPerGame
# Out:
# 114 131
# 1.1491228070175439

# %%
TottenhamGames = 0
TottenhamPoints = 0
for index, row in TottenhamData.iterrows():
  #print(row['Tottenham Result'])
  TottenhamGames += 1
  if row['Tottenham Result'] == 'Win':
    TottenhamPoints += 3
  elif row['Tottenham Result'] == 'Draw':
    TottenhamPoints +=1
print(TottenhamGames, TottenhamPoints)
TottenhamPointsPerGame = TottenhamPoints/TottenhamGames
print(TottenhamPointsPerGame)
TeamPPG['Tottenham'] = TottenhamPointsPerGame
# Out:
# 114 234
# 2.0526315789473686

# %%
SwanseaGames = 0
SwanseaPoints = 0
for index, row in SwanseaData.iterrows():
  #print(row['Swansea Result'])
  SwanseaGames += 1
  if row['Swansea Result'] == 'Win':
    SwanseaPoints += 3
  elif row['Swansea Result'] == 'Draw':
    SwanseaPoints +=1
print(SwanseaGames, SwanseaPoints)
SwanseaPointsPerGame = SwanseaPoints/SwanseaGames
print(SwanseaPointsPerGame)
TeamPPG['Swansea'] = SwanseaPointsPerGame
# Out:
# 76 74
# 0.9736842105263158

# %%
StokeGames = 0
StokePoints = 0
for index, row in StokeData.iterrows():
  #print(row['Stoke Result'])
  StokeGames += 1
  if row['Stoke Result'] == 'Win':
    StokePoints += 3
  elif row['Stoke Result'] == 'Draw':
    StokePoints +=1
print(StokeGames, StokePoints)
StokePointsPerGame = StokePoints/StokeGames
print(StokePointsPerGame)
TeamPPG['Stoke'] = StokePointsPerGame
# Out:
# 76 77
# 1.013157894736842

# %%
LeicesterGames = 0
LeicesterPoints = 0
for index, row in LeicesterData.iterrows():
  #print(row['Leicester Result'])
  LeicesterGames += 1
  if row['Leicester Result'] == 'Win':
    LeicesterPoints += 3
  elif row['Leicester Result'] == 'Draw':
    LeicesterPoints +=1
print(LeicesterGames, LeicesterPoints)
LeicesterPointsPerGame = LeicesterPoints/LeicesterGames
print(LeicesterPointsPerGame)
TeamPPG['Leicester'] = LeicesterPointsPerGame
# Out:
# 114 143
# 1.2543859649122806

# %%
ManUnitedGames = 0
ManUnitedPoints = 0
for index, row in ManUnitedData.iterrows():
  #print(row['ManUnited Result'])
  ManUnitedGames += 1
  if row['ManUnited Result'] == 'Win':
    ManUnitedPoints += 3
  elif row['ManUnited Result'] == 'Draw':
    ManUnitedPoints +=1
print(ManUnitedGames, ManUnitedPoints)
ManUnitedPointsPerGame = ManUnitedPoints/ManUnitedGames
print(ManUnitedPointsPerGame)
TeamPPG['ManUnited'] = ManUnitedPointsPerGame
# Out:
# 114 216
# 1.894736842105263

# %%
ChelseaGames = 0
ChelseaPoints = 0
for index, row in ChelseaData.iterrows():
  #print(row['Chelsea Result'])
  ChelseaGames += 1
  if row['Chelsea Result'] == 'Win':
    ChelseaPoints += 3
  elif row['Chelsea Result'] == 'Draw':
    ChelseaPoints +=1
print(ChelseaGames, ChelseaPoints)
ChelseaPointsPerGame = ChelseaPoints/ChelseaGames
print(ChelseaPointsPerGame)
TeamPPG['Chelsea'] = ChelseaPointsPerGame
# Out:
# 114 235
# 2.06140350877193

# %%
BournemouthGames = 0
BournemouthPoints = 0
for index, row in BournemouthData.iterrows():
  #print(row['Bournemouth Result'])
  BournemouthGames += 1
  if row['Bournemouth Result'] == 'Win':
    BournemouthPoints += 3
  elif row['Bournemouth Result'] == 'Draw':
    BournemouthPoints +=1
print(BournemouthGames, BournemouthPoints)
BournemouthPointsPerGame = BournemouthPoints/BournemouthGames
print(BournemouthPointsPerGame)
TeamPPG['Bournemouth'] = BournemouthPointsPerGame
# Out:
# 114 135
# 1.1842105263157894

# %%
ArsenalGames = 0
ArsenalPoints = 0
for index, row in ArsenalData.iterrows():
  #print(row['Arsenal Result'])
  ArsenalGames += 1
  if row['Arsenal Result'] == 'Win':
    ArsenalPoints += 3
  elif row['Arsenal Result'] == 'Draw':
    ArsenalPoints +=1
print(ArsenalGames, ArsenalPoints)
ArsenalPointsPerGame = ArsenalPoints/ArsenalGames
print(ArsenalPointsPerGame)
TeamPPG['Arsenal'] = ArsenalPointsPerGame
# Out:
# 114 208
# 1.8245614035087718

# %%
SouthamptonGames = 0
SouthamptonPoints = 0
for index, row in SouthamptonData.iterrows():
  #print(row['Southampton Result'])
  SouthamptonGames += 1
  if row['Southampton Result'] == 'Win':
    SouthamptonPoints += 3
  elif row['Southampton Result'] == 'Draw':
    SouthamptonPoints +=1
print(SouthamptonGames, SouthamptonPoints)
SouthamptonPointsPerGame = SouthamptonPoints/SouthamptonGames
print(SouthamptonPointsPerGame)
TeamPPG['Southampton'] = SouthamptonPointsPerGame
# Out:
# 114 121
# 1.0614035087719298

# %%
MiddlesbroughGames = 0
MiddlesbroughPoints = 0
for index, row in MiddlesbroughData.iterrows():
  #print(row['Middlesbrough Result'])
  MiddlesbroughGames += 1
  if row['Middlesbrough Result'] == 'Win':
    MiddlesbroughPoints += 3
  elif row['Middlesbrough Result'] == 'Draw':
    MiddlesbroughPoints +=1
print(MiddlesbroughGames, MiddlesbroughPoints)
MiddlesbroughPointsPerGame = MiddlesbroughPoints/MiddlesbroughGames
print(MiddlesbroughPointsPerGame)
TeamPPG['Middlesbrough'] = MiddlesbroughPointsPerGame
# Out:
# 38 28
# 0.7368421052631579

# %%
ManCityGames = 0
ManCityPoints = 0
for index, row in ManCityData.iterrows():
  #print(row['ManCity Result'])
  ManCityGames += 1
  if row['ManCity Result'] == 'Win':
    ManCityPoints += 3
  elif row['ManCity Result'] == 'Draw':
    ManCityPoints +=1
print(ManCityGames, ManCityPoints)
ManCityPointsPerGame = ManCityPoints/ManCityGames
print(ManCityPointsPerGame)
TeamPPG['ManCity'] = ManCityPointsPerGame
# Out:
# 114 276
# 2.4210526315789473

# %%
HullGames = 0
HullPoints = 0
for index, row in HullData.iterrows():
  #print(row['Hull Result'])
  HullGames += 1
  if row['Hull Result'] == 'Win':
    HullPoints += 3
  elif row['Hull Result'] == 'Draw':
    HullPoints +=1
print(HullGames, HullPoints)
HullPointsPerGame = HullPoints/HullGames
print(HullPointsPerGame)
TeamPPG['Hull'] = HullPointsPerGame
# Out:
# 38 34
# 0.8947368421052632

# %%
EvertonGames = 0
EvertonPoints = 0
for index, row in EvertonData.iterrows():
  #print(row['Everton Result'])
  EvertonGames += 1
  if row['Everton Result'] == 'Win':
    EvertonPoints += 3
  elif row['Everton Result'] == 'Draw':
    EvertonPoints +=1
print(EvertonGames, EvertonPoints)
EvertonPointsPerGame = EvertonPoints/EvertonGames
print(EvertonPointsPerGame)
TeamPPG['Everton'] = EvertonPointsPerGame
# Out:
# 114 164
# 1.4385964912280702

# %%
BurnleyGames = 0
BurnleyPoints = 0
for index, row in BurnleyData.iterrows():
  #print(row['Burnley Result'])
  BurnleyGames += 1
  if row['Burnley Result'] == 'Win':
    BurnleyPoints += 3
  elif row['Burnley Result'] == 'Draw':
    BurnleyPoints +=1
print(BurnleyGames, BurnleyPoints)
BurnleyPointsPerGame = BurnleyPoints/BurnleyGames
print(BurnleyPointsPerGame)
TeamPPG['Burnley'] = BurnleyPointsPerGame
# Out:
# 114 134
# 1.1754385964912282

# %%
CrystalPalaceGames = 0
CrystalPalacePoints = 0
for index, row in CrystalPalaceData.iterrows():
  #print(row['CrystalPalace Result'])
  CrystalPalaceGames += 1
  if row['CrystalPalace Result'] == 'Win':
    CrystalPalacePoints += 3
  elif row['CrystalPalace Result'] == 'Draw':
    CrystalPalacePoints +=1
print(CrystalPalaceGames, CrystalPalacePoints)
CrystalPalacePointsPerGame = CrystalPalacePoints/CrystalPalaceGames
print(CrystalPalacePointsPerGame)
TeamPPG['CrystalPalace'] = CrystalPalacePointsPerGame
CrystalPalaceData
# Out:
# 114 134
# 1.1754385964912282
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0    13/08/16  Crystal Palace       West Brom   0.0   1.0   A   0.0
# 1    E0    20/08/16       Tottenham  Crystal Palace   1.0   0.0   H   0.0
# 2    E0    27/08/16  Crystal Palace     Bournemouth   1.0   1.0   D   0.0
# 3    E0    10/09/16   Middlesbrough  Crystal Palace   1.0   2.0   A   1.0
# 4    E0    18/09/16  Crystal Palace           Stoke   4.0   1.0   H   2.0
# ..   ..         ...             ...             ...   ...   ...  ..   ...
# 109  E0  14/04/2019  Crystal Palace        Man City   1.0   3.0   A   0.0
# 110  E0  21/04/2019         Arsenal  Crystal Palace   2.0   3.0   A   0.0
# 111  E0  27/04/2019  Crystal Palace         Everton   0.0   0.0   D   0.0
# 112  E0  04/05/2019         Cardiff  Crystal Palace   2.0   3.0   A   1.0
# 113  E0  12/05/2019  Crystal Palace     Bournemouth   5.0   3.0   H   3.0
#
# ...

# %%
CardiffGames = 0
CardiffPoints = 0
for index, row in CardiffData.iterrows():
  #print(row['Cardiff Result'])
  CardiffGames += 1
  if row['Cardiff Result'] == 'Win':
    CardiffPoints += 3
  elif row['Cardiff Result'] == 'Draw':
    CardiffPoints +=1
print(CardiffGames, CardiffPoints)
CardiffPointsPerGame = CardiffPoints/CardiffGames
print(CardiffPointsPerGame)
TeamPPG['Cardiff'] = CardiffPointsPerGame
# Out:
# 38 34
# 0.8947368421052632

# %%
print(TeamPPG)
# Out:
# {'Wolves': 1.5, 'Fulham': 0.6842105263157895, 'Huddersfield': 0.6973684210526315, 'Newcastle': 1.1710526315789473, 'Brighton': 1.0, 'Liverpool': 2.175438596491228, 'WestHam': 1.219298245614035, 'Sunderland': 0.631578947368421, 'WestBrom': 1.0, 'Watford': 1.1491228070175439, 'Tottenham': 2.0526315789473686, 'Swansea': 0.9736842105263158, 'Stoke': 1.013157894736842, 'Leicester': 1.2543859649122806, 'ManUnited': 1.894736842105263, 'Chelsea': 2.06140350877193, 'Bournemouth': 1.1842105263157894, 'Arsenal': 1.8245614035087718, 'Southampton': 1.0614035087719298, 'Middlesbrough': 0.7368421052631579, 'ManCity': 2.4210526315789473, 'Hull': 0.8947368421052632, 'Everton': 1.4385964912280702, 'Burnley': 1.1754385964912282, 'CrystalPalace': 1.1754385964912282, 'Cardiff': 0.8947368421052632}

# %%
BestTeam = ''
WorstTeam = ''
BestPPG = 0
WorstPPG = 100
for key in TeamPPG:
  if TeamPPG[key] > BestPPG:
    BestTeam = key
    BestPPG = TeamPPG[key]
  elif TeamPPG[key] < WorstPPG:
    WorstTeam = key
    WorstPPG = TeamPPG[key]
print(BestTeam, BestPPG)
print(WorstTeam, WorstPPG)
# Out:
# ManCity 2.4210526315789473
# Sunderland 0.631578947368421
